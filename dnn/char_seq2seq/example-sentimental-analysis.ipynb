# %% [markdown]
# # Language correction - missing articles
#
# This notebook demonstrates a working example of applying the character-level sequence-to-sequence with attention model to address a language correction problem. We limit the scope of the problem to fixing a single missing article (a, an, the). This means that given an input text with an article missing, the model would recommend a language-corrected text as an output.

# %% [markdown]
# In particular, this notebook performs the following. Note that the majority of the codes are separated Python files inside the same folder (data_iterator.py, preprocessor.py, tf_graph.py, and training_manager.py).
# - Initial data investigation to see how the data look like
# - Data preprocessing, i.e., converting from raw data to the format that is ready to be trained by a Tensorflow graph for recurrent network modelling.
# - Splitting the data into three parts 1.) training set, 2.) validation set, and 3.) test set.
# - Specifying the hyperparameter for the training
# - Training a sequence-to-sequence model (with attention) on the training set and evaluate an accuracy metric on the validation set. The training stops when the loss metric on the validation set does not improve (using a simple early stopping method).
# - Saving the training model to files
# - Loading the training model
# - Evaluating the performance of the model qualitatively by using it on some random input data
# - Evaluating the performance of the model quantitatively by using the accuracy metric on the test set

# %% [markdown]
# Before you begin, please execute the following steps
# - Download the dataset archive file (missing_article.tar.gz) from https://github.com/rerngvit/dataset/blob/master/nlp/language_correction/missing_article.tar.gz
# - Extract the dataset to the same folder as this notebook. You expect to have the folder "dataset" after the extraction process

# %%
src_data_path  = "./dataset/kaggle-book/source.csv"
dest_data_path = "./dataset/kaggle-book/dest.csv"

# %% [markdown]
# # First let have a look at how the data look like

# %% [markdown]
# We read out the first 10 lines of the source and destination file

# %%
count = 1
for src_line, dest_line in zip(open(src_data_path, encoding='utf8'), 
                               open(dest_data_path, encoding='utf8')):
    print(src_line + dest_line)
    print("============")
    if count >= 5:
        break
    count = count + 1
# Out:
# The Da Vinci Code book is just awesome.
# 1
#
# ============
# "this was the first clive cussler i've ever read, but even books like Relic, and Da Vinci code were more plausible than this."
# 1
#
# ============
# i liked the Da Vinci Code a lot.
# 1
#
# ============
# i liked the Da Vinci Code a lot.
# 1
#
# ============
# I liked the Da Vinci Code but it ultimatly didn't seem to hold it's own.
# 1
#
# ============

# %% [markdown]
# The data represents a fixing of missing an article (at most one mistake) and a minor fixing of puncation.

# %% [markdown]
# # Let begin the training process

# %% [markdown]
# First we specify the folder that will store the trained models and Tensorboard data

# %%
model_base_dir = "./trained_models/sentimental_analysis"

# %% [markdown]
# First let have a look at the devices available for Tensorflow to train.
# You expect to see a GPU on the command below.
# Otherwise, the training process will be even longer than it normally would (15-20X+).

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17406597845783354212]

# %%
import numpy as np
import warnings
import matplotlib.pyplot as plt
import time
import os
import json
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.4.1'

# %%
from preprocessor import CharacterLevelSeq2SeqPreprocessor

# %%
lang_data_preprocessor = CharacterLevelSeq2SeqPreprocessor(src_data_path=src_data_path, 
               dest_data_path=dest_data_path, 
               max_number_of_samples=-1,
               max_character_length=80)
# Out:
#  Processing in total 5214 lines

# %% [markdown]
# Below is the hyper parameters used for the model

# %%
config = { 'hidden_units' : 256,
           'depth'     : 12,
           'attention_type' : 'Bahdanau',
           'use_embedding' :  True,
           'embedding_size' : 128,
           'num_encoder_symbols' : lang_data_preprocessor.num_src_tokens,
           'num_decoder_symbols' : lang_data_preprocessor.num_dest_tokens,
           'use_residual' : True,
           'attn_input_feeding': True,
           'use_dropout': True,
           'dropout_rate' : 0.02,
           'learning_rate' : 0.0005,
           'max_gradient_norm' : 1.0,
           'batch_size' : 64,
           'num_epochs' : 20,
           'optimizer'  : 'adam',
           'use_fp16'   : False,
           'max_src_seq_length'  : lang_data_preprocessor.max_src_seq_length,
           'max_dest_seq_length' : lang_data_preprocessor.max_dest_seq_length,
           'max_decode_step' : lang_data_preprocessor.max_dest_seq_length,
           'padding_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.PADDED_character],
           'dest_start_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.SEQ_START_CHARACTER],
           'dest_eos_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.EOS_character],
           'model_base_dir': model_base_dir,
           'model_saved_path' : model_base_dir + "/trained_model",
           'use_beamsearch_decode' : False,
           'beam_width' : 64,          
           'saving_last_model' : True,
           'default_device' : '/cpu:0',
           'run_full_trace': False
         }

# %%
from tf_graph import CharacterSeq2SeqModel
from data_iterator import DataFeedIterator
from training_manager import TrainingManager

# %%
training_manager = TrainingManager(lang_data_preprocessor=lang_data_preprocessor,
                                   src_data_path=src_data_path, 
                                   dest_data_path=dest_data_path, 
                                   batch_size=config["batch_size"])

# %%
import json
os.makedirs(model_base_dir, exist_ok=True)
cfg_file_path = model_base_dir + "/config.json"
with open(cfg_file_path, 'w') as file:
     file.write(json.dumps(config))

# %% [markdown]
# # The code below will start the training process
# * Note that it is expected to take around 15-20 hours for a single run (with a GPU). If you do not have a GPU, it can take even longer than that.
# * After the training process is finished. The model would be saved to a file

# %%
training_manager.fit_eval_dnn(config=config)
# Out:
#  Setting default device to  /cpu:0
# building model..
# building encoder..
# building decoder and attention..
#  Initial state for decoder cell batch size is  64
#  Decoder input encoded is  (64, 3, 256)
# logits train shape is  (64, ?, 5)
# decoder_targets_train train shape is  (64, ?)
# setting optimizer..
# running vars are  [<tf.Variable 'decoder/accuracy/total:0' shape=() dtype=float32_ref>, <tf.Variable 'decoder/accuracy/count:0' shape=() dtype=float32_ref>]
# Execution an epoch: type =  Train
# [ Train ] Epoch 0 Step 0 Teacher-Force Acc 0.18 Loss 0.66 Perplex 1.94 Elapsed Time 1.93 3.32 samples/s Cur time:  2018-02-02 08:43
#
# [ Train ] Epoch 0 Step 10 Teacher-Force Acc 0.77 Loss 2.94 Perplex 18.99 Elapsed Time 17.39 3.68 samples/s Cur time:  2018-02-02 08:46
#
# [ Train ] Epoch 0 Step 20 Teacher-Force Acc 0.86 Loss 0.45 Perplex 1.56 Elapsed Time 17.88 3.58 samples/s Cur time:  2018-02-02 08:49
#
# [ Train ] Epoch 0 Step 30 Teacher-Force Acc 0.90 Loss 0.19 Perplex 1.21 Elapsed Time 19.17 3.34 samples/s Cur time:  2018-02-02 08:52
#
# [ Train ] Epoch 0 Step 40 Teacher-Force Acc 0.92 Loss 0.20 Perplex 1.22 Elapsed Time 16.37 3.91 samples/s Cur time:  2018-02-02 08:55
#
#  Finishing an epoch type  Train  with agg_loss =  0.07390946596860885
# Execution an epoch: type =  Validation
# [ Validation ] Epoch 0 Step 0 Teacher-Force Acc 0.99 Loss 0.00 Perplex 1.00 Elapsed Time 1.12 5.70 samples/s Cur time:  2018-02-02 08:56
#
# [ Validation ] Epoch 0 Step 10 Teacher-Force Acc 0.99 Loss 0.14 Perplex 1.15 Elapsed Time 11.92 5.37 samples/s Cur time:  2018-02-02 08:58
#
#  Finishing an epoch type  Validation  with agg_loss =  0.1447853662073612
#  Get avg loss of  0.07259448310360313
# Cost score is not Nan
# Hist cost score is []
#  no history yet -> not increasing score
# Should continue training - best valid metric is inf, avg_loss is 0.07259448310360313
# Got a new best valid metric of  0.07259448310360313
# Saving the last model.. at  ./trained_models/sentimental_analysis/trained_model
# model saved at ./trained_models/sentimental_analysis/trained_model
# Epoch 1 DONE
# Execution an epoch: type =  Train
# [ Train ] Epoch 1 Step 0 Teacher-Force Acc 0.97 Loss 0.02 Perplex 1.02 Elapsed Time 1.61 3.99 samples/s Cur time:  2018-02-02 09:00
#
# [ Train ] Epoch 1 Step 10 Teacher-Force Acc 0.98 Loss 0.17 Perplex 1.18 Elapsed Time 17.76 3.60 samples/s Cur time:  2018-02-02 09:03
#
# [ Train ] Epoch 1 Step 20 Teacher-Force Acc 0.99 Loss 0.14 Perplex 1.15 Elapsed Time 19.35 3.31 samples/s Cur time:  2018-02-02 09:06
#
# [ Train ] Epoch 1 Step 30 Teacher-Force Acc 0.99 Loss 0.12 Perplex 1.12 Elapsed Time 26.81 2.39 samples/s Cur time:  2018-02-02 09:11
#
# [ Train ] Epoch 1 Step 40 Teacher-Force Acc 0.98 Loss 0.26 Perplex 1.30 Elapsed Time 32.19 1.99 samples/s Cur time:  2018-02-02 09:16
#
#  Finishing an epoch type  Train  with agg_loss =  0.046630529873073104
# Execution an epoch: type =  Validation
# [ Validation ] Epoch 1 Step 0 Teacher-Force Acc 1.00 Loss 0.00 Perplex 1.00 Elapsed Time 1.53 4.18 samples/s Cur time:  2018-02-02 09:19
#
# [ Validation ] Epoch 1 Step 10 Teacher-Force Acc 0.99 Loss 0.17 Perplex 1.18 Elapsed Time 14.51 4.41 samples/s Cur time:  2018-02-02 09:21
#
#  Finishing an epoch type  Validation  with agg_loss =  0.1809039071202278
#  Get avg loss of  0.08362909736461005
# Cost score is not Nan
# Hist cost score is [0.07259448310360313]
#  Increasing patient count
# Should continue training - best valid metric is 0.07259448310360313, avg_loss is 0.08362909736461005
# Epoch 2 DONE
# Execution an epoch: type =  Train
# [ Train ] Epoch 2 Step 0 Teacher-Force Acc 1.00 Loss 0.00 Perplex 1.00 Elapsed Time 2.96 2.16 samples/s Cur time:  2018-02-02 09:24
#
# [ Train ] Epoch 2 Step 10 Teacher-Force Acc 0.99 Loss 0.14 Perplex 1.15 Elapsed Time 36.76 1.74 samples/s Cur time:  2018-02-02 09:30
#
# [ Train ] Epoch 2 Step 20 Teacher-Force Acc 0.99 Loss 0.10 Perplex 1.10 Elapsed Time 33.19 1.93 samples/s Cur time:  2018-02-02 09:36
#
# [ Train ] Epoch 2 Step 30 Teacher-Force Acc 0.99 Loss 0.17 Perplex 1.18 Elapsed Time 29.01 2.21 samples/s Cur time:  2018-02-02 09:40
#
# [ Train ] Epoch 2 Step 40 Teacher-Force Acc 0.99 Loss 0.11 Perplex 1.12 Elapsed Time 31.68 2.02 samples/s Cur time:  2018-02-02 09:46
#
#  Finishing an epoch type  Train  with agg_loss =  0.026956103555858132
# Execution an epoch: type =  Validation
# [ Validation ] Epoch 2 Step 0 Teacher-Force Acc 0.99 Loss 0.00 Perplex 1.00 Elapsed Time 1.51 4.25 samples/s Cur time:  2018-02-02 09:48
#
# [ Validation ] Epoch 2 Step 10 Teacher-Force Acc 0.99 Loss 0.14 Perplex 1.15 Elapsed Time 14.30 4.48 samples/s Cur time:  2018-02-02 09:50
#
#  Finishing an epoch type  Validation  with agg_loss =  0.1433797776699066
#  Get avg loss of  0.07141225822269916
# Cost score is not Nan
# Hist cost score is [0.07259448310360313, 0.08362909736461005]
#  Increasing patient count
# Should continue training - best valid metric is 0.07259448310360313, avg_loss is 0.07141225822269916
# Got a new best valid metric of  0.07141225822269916
# Saving the last model.. at  ./trained_models/sentimental_analysis/trained_model
# model saved at ./trained_models/sentimental_analysis/trained_model
# Epoch 3 DONE
# Execution an epoch: type =  Train
# [ Train ] Epoch 3 Step 0 Teacher-Force Acc 0.99 Loss 0.01 Perplex 1.01 Elapsed Time 3.54 1.81 samples/s Cur time:  2018-02-02 09:53
#
# [ Train ] Epoch 3 Step 10 Teacher-Force Acc 0.99 Loss 0.11 Perplex 1.11 Elapsed Time 29.78 2.15 samples/s Cur time:  2018-02-02 09:58
#
# [ Train ] Epoch 3 Step 20 Teacher-Force Acc 0.99 Loss 0.08 Perplex 1.09 Elapsed Time 30.37 2.11 samples/s Cur time:  2018-02-02 10:03
#
# [ Train ] Epoch 3 Step 30 Teacher-Force Acc 0.99 Loss 0.06 Perplex 1.06 Elapsed Time 28.12 2.28 samples/s Cur time:  2018-02-02 10:08
#
# [ Train ] Epoch 3 Step 40 Teacher-Force Acc 0.99 Loss 0.12 Perplex 1.13 Elapsed Time 25.96 2.47 samples/s Cur time:  2018-02-02 10:12
#
#  Finishing an epoch type  Train  with agg_loss =  0.03447478152811527
# Execution an epoch: type =  Validation
# [ Validation ] Epoch 3 Step 0 Teacher-Force Acc 1.00 Loss 0.00 Perplex 1.00 Elapsed Time 1.18 5.43 samples/s Cur time:  2018-02-02 10:14
#
# [ Validation ] Epoch 3 Step 10 Teacher-Force Acc 0.99 Loss 0.15 Perplex 1.16 Elapsed Time 12.71 5.03 samples/s Cur time:  2018-02-02 10:16
#
#  Finishing an epoch type  Validation  with agg_loss =  0.1655368734151125
#  Get avg loss of  0.07381263534771279
# Cost score is not Nan
# Hist cost score is [0.07259448310360313, 0.08362909736461005, 0.07141225822269916]
#  Increasing patient count
# An early stop condition triggered => early stopping...
#  Best average validation metric = 0.07141225822269916
# 0.07141225822269916

# %% [markdown]
# # Loading the trained model from the saved file

# %%
import json

# %%
loaded_config = json.load(open(cfg_file_path))
loaded_config
# Out:
# {'attention_type': 'Bahdanau',
#  'attn_input_feeding': True,
#  'batch_size': 64,
#  'beam_width': 64,
#  'default_device': '/cpu:0',
#  'depth': 12,
#  'dest_eos_token_index': 1,
#  'dest_start_token_index': 2,
#  'dropout_rate': 0.02,
#  'embedding_size': 128,
#  'hidden_units': 256,
#  'learning_rate': 0.0005,
#  'max_decode_step': 3,
#  'max_dest_seq_length': 3,
#  'max_gradient_norm': 1.0,
#  'max_src_seq_length': 80,
#  'model_base_dir': './trained_models/sentimental_analysis',
#  'model_saved_path': './trained_models/sentimental_analysis/trained_model',
#  'num_decoder_symbols': 5,
#  'num_encoder_symbols': 95,
#  'num_epochs': 20,
#  'optimizer': 'adam',
#  'padding_token_index': 0,
#  'run_full_trace': False,
#  'saving_last_model': True,
#  'use_beamsearch_decode': False,
#  'use_dropout': True,
#  'use_embedding': True,
#  'use_fp16': False,
#  'use_residual': True}

# %%
decoding_config = {
    'beam_width': 1,
    'use_beamsearch_decode' : False,
    'max_decode_step': lang_data_preprocessor.max_dest_seq_length,
    'write_n_best' : False,
    'log_device_placement' : True,
    'batch_size': 32,
    'default_device' : '/cpu:0'
    
}

# %%
for k, v in loaded_config.items():
    if k not in decoding_config.keys():
        decoding_config[k] = v

# %%
decoding_config
# Out:
# {'attention_type': 'Bahdanau',
#  'attn_input_feeding': True,
#  'batch_size': 32,
#  'beam_width': 1,
#  'default_device': '/cpu:0',
#  'depth': 12,
#  'dest_eos_token_index': 1,
#  'dest_start_token_index': 2,
#  'dropout_rate': 0.02,
#  'embedding_size': 128,
#  'hidden_units': 256,
#  'learning_rate': 0.0005,
#  'log_device_placement': True,
#  'max_decode_step': 3,
#  'max_dest_seq_length': 3,
#  'max_gradient_norm': 1.0,
#  'max_src_seq_length': 80,
#  'model_base_dir': './trained_models/sentimental_analysis',
#  'model_saved_path': './trained_models/sentimental_analysis/trained_model',
#  'num_decoder_symbols': 5,
#  'num_encoder_symbols': 95,
#  'num_epochs': 20,
#  'optimizer': 'adam',
#  'padding_token_index': 0,
#  'run_full_trace': False,
#  'saving_last_model': True,
#  'use_beamsearch_decode': False,
#  'use_dropout': True,
#  'use_embedding': True,
#  'use_fp16': False,
#  'use_residual': True,
#  'write_n_best': False}

# %%
import tensorflow as tf
tf.reset_default_graph() # to clean out all the variables to allow for rerunning the model
sess = tf.Session(config=tf.ConfigProto(
      allow_soft_placement=True))

# %%
# Start the model
decoding_model = CharacterSeq2SeqModel(session=sess,
                              config=decoding_config, 
                              mode='decode')
# Restoring model parameters
decoding_model.restore(sess, decoding_config["model_saved_path"])
# Out:
#  Setting default device to  /cpu:0
# building model..
# building encoder..
# building decoder and attention..
#  Initial state for decoder cell batch size is  32
# building greedy decoder..
# INFO:tensorflow:Restoring parameters from ./trained_models/sentimental_analysis/trained_model
# model restored from ./trained_models/sentimental_analysis/trained_model

# %% [markdown]
# # Evaluating the model qualitatively with unseen data

# %%
def sentimental_analysis(input_text):
    return training_manager.seq2seq_execution(
    sess, decoding_model, decoding_config['batch_size'], 
    input_text=input_text)

# %%
sentimental_analysis("This is a great movie.")
# Out:
# '0\n'

# %%
sentimental_analysis("Awesome movie.")
# Out:
# '1\n'

# %%
sentimental_analysis("I really like it.")

# %%
sentimental_analysis("Such a lovely movie.")

# %%
sentimental_analysis("I do not like this one at all.")
# Out:
# '1\n'

# %%
sentimental_analysis("This sucks.")
# Out:
# '0\n'

# %%
sentimental_analysis("I hate this completely.")
# Out:
# '0\n'

# %%
sentimental_analysis("This sucks big time!")
# Out:
# '0\n'

# %%
sentimental_analysis("This is a very bad movie.")
# Out:
# '0\n'

# %% [markdown]
# # Evaluating the model quantitatively on the test set

# %% [markdown]
# The code below simply retrieve the data as a batch and using the model to generate the predictions (decoded_text)
# and compare with the ground truth (dest text). At the end of the evaluation, the code would output the accuracy metric, which is the fraction of samples that are matched between the ground truth and the predictions.

# %%
def evaluate_model(dataset):
    num_samples, num_corrected = 0, 0
    
    for source, source_len, dest, dest_len in dataset:
        for sample_idx in range(config['batch_size']):
            beam_idx = 0
            decoding_src_seq  = source[sample_idx, :]
            decoding_dest_seq = dest[sample_idx, :]
            
            input_text = lang_data_preprocessor.src_seq_to_text(decoding_src_seq)
            predicted_text = language_correction_text(input_text)
            actual_text = lang_data_preprocessor.dest_seq_to_text(
                decoding_dest_seq)[1:]   # Ignoring the first SEQ_START chracter
            
            print("Input text = '%s'"     % input_text)
            print("Dest text = '%s'"     %  actual_text)
            print("Decoded text = '%s'  " % predicted_text)
            print(" =======================")
            
            if actual_text.strip() == predicted_text.strip():
                num_corrected += 1
            
            num_samples += 1
    
    print(" Number of corrected decoding = ", num_corrected, ", out of ", num_samples)
    accuracy = (num_corrected + 0.0) / num_samples
    print(" Accuracy = %s " % accuracy)

# %%
train_data_list = list(training_manager.train_set)
train_data_list
# Out:
# [(array([[44., 71., 81., ...,  0.,  0.,  0.],
#          [ 5., 64., 87., ...,  0.,  0.,  0.],
#          [ 5., 50., 82., ...,  0.,  0.,  0.],
#          ...,
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          [17., 35., 77., ...,  0.,  0.,  0.],
#          [ 5., 39., 63., ...,  0.,  0.,  0.]]),
#   array([36, 65, 75, 33, 78, 33, 35, 22, 35, 31, 77, 27, 65, 34, 68, 49, 42,
#          67, 38, 72, 31, 76, 33, 27, 49, 71, 78, 54, 54, 33, 71, 76, 38, 31,
#          62, 77, 54, 31, 33, 30, 49, 30, 43, 76, 23, 30, 30, 35, 21, 42, 27,
#          79, 27, 52, 39, 58, 78, 23, 23, 41, 38, 23, 58, 70]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[82., 70., 67., ...,  0.,  0.,  0.],
#          [66., 83., 66., ...,  0.,  0.,  0.],
#          [44., 87.,  3., ...,  0.,  0.,  0.],
#          ...,
#          [66., 63.,  3., ...,  0.,  0.,  0.],
#          [33., 80., 77., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0
),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[33., 49., 46., ...,  0.,  0.,  0.],
#          [ 5., 39., 67., ...,  0.,  0.,  0.],
#          [40.,  3., 70., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 70., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          [17., 40.,  3., ...,  0.,  0.,  0.]]),
#   array([52, 63, 21, 21, 66, 22, 78, 38, 66, 35, 54, 26, 65, 45, 49, 54, 48,
#          38, 60, 31, 68, 50, 21, 30, 39, 21, 43, 80, 21, 39, 35, 63, 52, 36,
#          21, 43, 43, 21, 41, 67, 33, 47, 54, 68, 77, 35, 63, 43, 72, 22, 30,
#          35, 21, 21, 42, 78, 38, 21, 67, 43, 36, 21, 42, 30]),
#   array([[2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[75., 63., 76., ...,  0.,  0.,  0.],
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          ...,
#          [75., 63., 76., ...,  0.,  0.,  0.],
#          [ 5., 32., 76., ...,  0.,  0.,  0.],
#          [ 5., 64., 87., ...,  0.,  0.,  0.]]),
#   array([32, 26, 31, 44, 76, 32, 68, 26, 60, 46, 60, 75, 43, 72, 30, 26, 27,
#          33, 33, 41, 71, 54, 21, 45, 72, 31, 59, 63, 35, 76, 45, 68, 35, 52,
#          41, 21, 36, 31, 39, 60, 30, 21, 68, 63, 67, 23, 52, 39, 31, 21, 41,
#          50, 62, 33, 43, 64, 60, 21, 41, 40, 48, 32, 50, 65]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[ 5., 35., 63., ...,  0.,  0.,  0.],
#          [71.,  3., 70., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          ...,
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          [ 5., 32., 74., ...,  0.,  0.,  0.],
#          [44., 87.,  3., ...,  0.,  0.,  0.]]),
#   array([76, 54, 22, 64, 64, 35, 39, 33, 48, 51, 32, 36, 72, 21, 39, 30, 31,
#          76, 65, 22, 31, 33, 22, 64, 38, 35, 63, 31, 36, 76, 56, 26, 31, 23,
#          48, 54, 27, 51, 52, 54, 76, 33, 25, 27, 48, 38, 35, 68, 46, 21, 48,
#          73, 48, 27, 21, 54, 27, 21, 26, 65, 38, 23, 64, 50]),
#   array([[2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[66., 83., 66., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          [33., 80., 77., ...,  0.,  0.,  0.],
#          ...,
#          [33., 80., 77., ...,  0.,  0.,  0.],
#          [82., 70., 67., ...,  0.,  0.,  0.],
#          [64., 80., 77., ...,  0.,  0.,  0.]]),
#   array([38, 39, 33, 38, 43, 38, 27, 38, 42, 36, 33, 50, 41, 57, 28, 45, 21,
#          52, 42, 31, 28, 45, 68, 38, 23, 60, 21, 35, 23, 44, 78, 43, 77, 76,
#          27, 41, 24, 39, 27, 41, 76, 39, 39, 38, 63, 51, 26, 28, 25, 34, 32,
#          30, 35, 77, 31, 43, 66, 30, 58, 36, 28, 41, 66, 34]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[51., 70., 67., ...,  0.,  0.,  0.],
#          [39., 63., 80., ...,  0.,  0.,  0.],
#          [ 5., 64., 87., ...,  0.,  0.,  0.],
#          ...,
#          [66., 63.,  3., ...,  0.,  0.,  0.],
#          [ 5., 64., 87., ...,  0.,  0.,  0.],
#          [ 5., 64., 87., ...,  0.,  0.,  0.]]),
#   array([31, 67, 65, 66, 42, 35, 39, 21, 51, 73, 78, 33, 23, 79, 30, 23, 32,
#          27, 41, 26, 60, 72, 32, 31, 35, 32, 68, 23, 68, 21, 21, 66, 48, 41,
#          52, 27, 21, 50, 76, 27, 41, 21, 48, 50, 52, 38, 72, 38, 28, 43, 60,
#          64, 42, 72, 34, 34, 67, 68, 27, 20, 33, 23, 65, 65]),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([
),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[49., 53.,  3., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0.],
#          ...,
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0.]]),
#   array([60, 52, 52, 52, 77, 68, 28, 36, 74, 35, 36, 36, 63, 31, 54, 78, 65,
#          77, 74, 60, 38, 21, 32, 30, 58, 30, 38, 21, 23, 76, 30, 51, 60, 72,
#          32, 50, 63, 21, 23, 36, 64, 58, 21, 50, 52, 38, 27, 26, 30, 32, 72,
#          43, 30, 38, 33, 31, 29, 23, 72, 42, 26, 46, 27, 51]),
#   array([[2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[66., 63.,  3., ...,  0.,  0.,  0.],
#          [44., 87.,  3., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          ...,
#          [44., 71., 81., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0.],
#          [35., 63.,  3., ...,  0.,  0.,  0.]]),
#   array([38, 50, 21, 43, 30, 38, 52, 52, 39, 66, 23, 51, 29, 27, 38, 72, 31,
#          64, 45, 36, 21, 31, 78, 72, 65, 32, 26, 77, 66, 68, 38, 38, 36, 38,
#          63, 26, 53, 35, 38, 30, 41, 64, 34, 47, 33, 21, 39, 31, 33, 68, 36,
#          23, 71, 36, 51, 47, 60, 28, 78, 31, 50, 36, 51, 23]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[17., 33., 80., ...,  0.,  0.,  0.],
#          [39., 63., 80., ...,  0.,  0.,  0.],
#          [ 5., 40.,  3., ...,  0.,  0.,  0.],
#          ...,
#          [44., 71., 81., ...,  0.,  0.,  0.],
#          [75., 71., 81., ...,  0.,  0.,  0.],
#          [40.,  3., 75., ...,  0.,  0.,  0.]]),
#   array([42, 31, 43, 38, 54, 31, 77, 36, 33, 50, 30, 31, 32, 39, 30, 28, 72,
#          39, 21, 59, 32, 37, 58, 58, 48, 66, 36, 58, 27, 52, 21, 28, 50, 31,
#          41, 21, 77, 68, 47, 37, 66, 71, 76, 42, 36, 30, 76, 38, 72, 65, 52,
#          71, 64, 22, 40, 32, 63, 31, 31, 21, 48, 36, 33, 55]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[68., 80., 71., ...,  1.,  0.,  0.],
#          [70., 77., 74., ...,  0.,  0.,  0.],
#          [68., 80., 71., ...,  1.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [ 5., 51., 70., ...,  0.,  0.,  0.],
#          [40.,  3., 43., ...,  0.,  0.,  0.]]),
#   array([78, 41, 78, 42, 53, 31, 21, 54, 52, 30, 47, 76, 48, 60, 48, 43, 43,
#          23, 48, 33, 36, 31, 63, 41, 21, 33, 48, 72, 27, 48, 26, 23, 21, 71,
#          66, 78, 72, 53, 30, 72, 23, 38, 67, 23, 22, 36, 47, 58, 42, 36, 52,
#          67, 38, 76, 35, 40, 38, 26, 66, 43, 72, 35, 60, 28]),
#   array([[2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[35., 63.,  3., ...,  0.,  0.,  0.],
#          [44., 71., 81., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.],
#          [51., 70., 67., ...,  0.,  0.,  0.]]),
#   array([26, 36, 39, 39, 68, 36, 67, 45, 41, 78, 27, 48, 60, 63, 45, 35, 77,
#          72, 41, 30, 42, 31, 35, 23, 36, 50, 63, 26, 43, 23, 39, 68, 45, 60,
#          41, 43, 38, 23, 30, 36, 39, 29, 48, 52, 48, 52, 38, 42, 28, 49, 48,
#          64, 26, 65, 31, 54, 58, 33, 38, 63, 67, 30, 42, 31]),
#   array([[2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[66., 83., 66., ...,  0.,  0.,  0.],
# ...
#  (array([[ 5., 81., 77., ...,  5.,  1.,  0.],
#          [ 5., 40.,  3., ...,  0.,  0.,  0.],
#          [44., 71., 81., ...,  0.,  0.,  0.],
#          ...,
#          [ 5., 51., 70., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [85., 67.,  7., ...,  0.,  0.,  0.]]),
#   array([79, 43, 36, 50, 27, 38, 68, 54, 52, 35, 72, 66, 33, 58, 51, 21, 21,
#          65, 35, 54, 58, 61, 58, 48, 41, 26, 39, 77, 33, 38, 33, 50, 23, 39,
#          56, 27, 50, 38, 68, 39, 50, 63, 60, 21, 28, 38, 67, 33, 21, 27, 31,
#          35, 43, 30, 60, 38, 38, 31, 30, 28, 35, 60, 21, 52]),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[40.,  3., 85., ...,  0.,  0.,  0.],
#          [ 5., 40., 81., ...,  0.,  0.,  0.],
#          [71.,  3., 74., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [ 5., 46., 70., ...,  0.,  0.,  0.],
#          [ 5., 40.,  3., ...,  0.,  0.,  0.]]),
#   array([58, 47, 27, 31, 45, 30, 27, 23, 48, 22, 78, 27, 23, 79, 58, 23, 64,
#          26, 48, 52, 42, 41, 58, 29, 28, 35, 35, 50, 71, 43, 50, 36, 23, 67,
#          50, 58, 72, 63, 39, 33, 27, 38, 58, 52, 66, 30, 33, 66, 21, 21, 31,
#          66, 50, 36, 29, 38, 26, 21, 35, 45, 27, 21, 52, 71]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[35., 32.,  3., ...,  0.,  0.,  0.],
#          [71.,  3., 74., ...,  0.,  0.,  0.],
#          [66., 83., 66., ...,  0.,  0.,  0.],
#          ...,
#          [39., 63., 80., ...,  0.,  0.,  0.],
#          [43., 77., 84., ...,  0.,  0.,  0.],
#          [40.,  3., 85., ...,  0.,  0.,  0.]]),
#   array([27, 72, 38, 28, 30, 21, 46, 51, 38, 28, 31, 57, 28, 63, 48, 47, 33,
#          58, 66, 35, 54, 27, 66, 36, 66, 21, 52, 76, 41, 48, 44, 36, 50, 36,
#          21, 38, 41, 72, 25, 36, 27, 22, 77, 71, 52, 36, 27, 23, 39, 31, 68,
#          43, 31, 27, 41, 50, 68, 54, 43, 36, 39, 49, 33, 58]),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[ 5., 32., 74., ...,  0.,  0.,  0.],
#          [40.,  3., 85., ...,  0.,  0.,  0.],
#          [44., 71., 81., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [ 5., 35., 63., ...,  0.,  0.,  0.],
#          [66., 63.,  3., ...,  0.,  0.,  0.]]),
#   array([64, 58, 36, 35, 43, 26, 23, 50, 26, 41, 38, 38, 39, 36, 60, 21, 35,
#          27, 40, 35, 76, 31, 26, 27, 66, 21, 23, 27, 50, 39, 53, 60, 41, 38,
#          54, 64, 27, 21, 35, 67, 54, 68, 50, 36, 65, 36, 35, 32, 67, 31, 31,
#          36, 62, 68, 21, 27, 42, 70, 41, 58, 76, 21, 76, 23]),
#   array([[2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[82., 70., 67., ...,  0.,  0.,  0.],
#          [71.,  3., 70., ...,  0.,  0.,  0.],
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [ 5., 40., 12., ...,  0.,  0.,  0.],
#          [81., 82., 83., ...,  0.,  0.,  0.]]),
#   array([26, 54, 22, 63, 31, 65, 48, 39, 32, 50, 23, 72, 23, 32, 72, 30, 42,
#          41, 63, 71, 60, 51, 31, 41, 41, 47, 63, 47, 26, 67, 23, 63, 71, 46,
#          52, 31, 43, 21, 21, 30, 33, 38, 50, 64, 26, 33, 27, 31, 21, 21, 38,
#          39, 72, 72, 48, 61, 31, 50, 45, 42, 73, 21, 30, 48]),
#   array([[2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[75., 71., 81., ...,  0.,  0.,  0.],
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          [35., 63.,  3., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [16., 40.,  3., ...,  0.,  0.,  0.]]),
#   array([33, 21, 26, 67, 38, 63, 35, 28, 61, 72, 32, 67, 76, 36, 31, 67, 65,
#          65, 66, 58, 39, 21, 27, 67, 52, 41, 51, 22, 27, 36, 60, 21, 21, 30,
#          52, 63, 22, 28, 26, 48, 36, 52, 77, 42, 32, 31, 72, 78, 52, 33, 31,
#          31, 47, 50, 30, 58, 31, 53, 26, 35, 21, 22, 22, 23]),
#   array([[2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])),
#  (array([[40.,  3., 74., ...,  0.,  0.,  0.],
#          [33., 80., 77., ...,  0.,  0.,  0.],
#          [39., 63., 80., ...,  0.,  0.,  0.],
#          ...,
#          [40.,  3., 74., ...,  0.,  0.,  0.],
#          [82., 70., 67., ...,  0.,  0.,  0.],
#          [40.,  3., 74., ...,  0.,  0.,  0.]]),
#   array([21, 36, 67, 36, 59, 42, 27, 64, 57, 43, 45, 23, 23, 38, 39, 47, 39,
#          52, 31, 64, 48, 32, 68, 21, 30, 35, 48, 32, 30, 33, 66, 51, 72, 30,
#          45, 51, 48, 30, 36, 79, 43, 72, 22, 38, 23, 27, 60, 21, 77, 41, 27,
#          34, 38, 23, 22, 63, 76, 50, 77, 41, 21, 21, 66, 28]),
#   array([[2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 3., 1.],
#          [2., 3., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.],
#          [2., 4., 1.]]),
#   array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]))]

# %%
import random

# %% [markdown]
# First, let evaluate the performance on the training set. We do data sampling here with *k* representing the number of batches to obtain early results before progressing to larger *k*

# %%
evaluate_model(random.sample(train_data_list, k=2))
# Out:
# Input text = 'friday hung out with kelsie and we went and saw The Da Vinci Code SUCKED!!!!!
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'holy crap i loved mission impossible 3..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'friday hung out with kelsie and we went and saw The Da Vinci Code SUCKED!!!!!
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'The Da Vinci Code was absolutely AWESOME!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I have to say, I hated Brokeback Mountain, though."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Brokeback Mountain was boring.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'i heard da vinci code sucked soo much only 2.5 stars:
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'we're gonna like watch Mission Impossible or Hoot.(
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I, too, like Harry Potter.."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"Is it just me, or does Harry Potter suck?..."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"Da Vinci Code = Up, Up, Down, Down, Left, Right, Left, Right, B, A, SUCK!"
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'This quiz sucks and Harry Potter sucks ok bye..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"The Da Vinci Code was awesome, I can't wait to read it..."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'This quiz sucks and Harry Potter sucks ok bye..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"I liked the first "" Mission Impossible."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I liked the first "" Mission Impossible."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Ok brokeback mountain is such a horrible movie.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'mission impossible 2 rocks!!....
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'how much the da vinci code sucks...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'The Da Vinci Code is AWESOME!.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"He's like,'YEAH I GOT ACNE AND I LOVE BROKEBACK MOUNTAIN '.."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback Mountain was an AWESOME movie.
# '
# Dest text = '1
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Love luv lubb the Da Vinci Code!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Ok brokeback mountain is such a horrible movie.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Brokeback Mountain.
# '
# Dest text = '0
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'This quiz sucks and Harry Potter sucks ok bye..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Da Vinci Code sucks be...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I hate Harry Potter, that daniel wotshisface needs a fucking slap..."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'the last stand and Mission Impossible 3 both were awesome movies.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'friday hung out with kelsie and we went and saw The Da Vinci Code SUCKED!!!!!
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'which made me realize how much I love Harry Potter..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Brokeback Mountain....
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'dudeee i LOVED brokeback mountain!!!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Harry Potter is AWESOME I don't care if anyone says differently!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I love Harry Potter..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback mountain was beautiful...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"Is it just me, or does Harry Potter suck?..."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I wanted desperately to love'The Da Vinci Code as a film.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'The Da Vinci Code was absolutely AWESOME!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Mission Impossible 3 was excellent.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'we're gonna like watch Mission Impossible or Hoot.(
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Harry Potter is AWESOME I don't care if anyone says differently!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'The Da Vinci Code is an awesome book.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"Da Vinci Code = Up, Up, Down, Down, Left, Right, Left, Right, B, A, SUCK!"
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'The Da Vinci Code sucked big time.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'The Da Vinci Code book is just awesome.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'da vinci code was an awesome movie...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucks be...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'the last stand and Mission Impossible 3 both were awesome movies.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'mission impossible 3 was an awesome movie.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I loved seeing Mission Impossible:
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"The Da Vinci Code was awesome, I can't wait to read it..."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I LOVE BROKEBACK MOUNTAIN..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Brokeback Mountain....
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"The Da Vinci Code was awesome, I can't wait to read it..."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'friday hung out with kelsie and we went and saw The Da Vinci Code SUCKED!!!!!
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'da vinci code sucks...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'dudeee i LOVED brokeback mountain!!!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Harry Potter is AWESOME I don't care if anyone says differently!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'we're gonna like watch Mission Impossible or Hoot.(
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I really love Brokeback Mountain, its a wonderful film!!!"
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I liked the first "" Mission Impossible."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'thirdly-the da vinci code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '

# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-ed9684a85977> in <module>()
# ----> 1 evaluate_model(random.sample(train_data_list, k=10))
#
# <ipython-input-81-ccd6a45764c2> in evaluate_model(dataset)
#       9
#      10             input_text = lang_data_preprocessor.src_seq_to_text(decoding_src_seq)
# ---> 11             predicted_text = language_correction_text(input_text)
#      12             actual_text = lang_data_preprocessor.dest_seq_to_text(
#      13                 decoding_dest_seq)[1:]   # Ignoring the first SEQ_START chracter
#
# <ipython-input-67-157115260d44> in language_correction_text(input_text)
#       2     return training_manager.seq2seq_execution(
#       3     sess, decoding_model, decoding_config['batch_size'],
# ----> 4     input_text=input_text)
#
# /data/training_manager.py in seq2seq_execution(self, sess, decoding_model, batch_size, input_text)
#     312         decoded_output = decoding_model.predict(
#     313             sess,  encoder_inputs=batch_of_input_seq,
# --> 314             encoder_inputs_length=batch_of_length_seq)
#     315         # Extracting the first row of output
#     316         first_row_out = decoded_output[0, :, :]
#
# /data/tf_graph.py in predict(self, sess, encoder_inputs, encoder_inputs_length)
#     495         input_feed[self.keep_prob_placeholder.name] = 1.0
#     496         output_feed = [self.decoder_pred_decode]
# --> 497         outputs = sess.run(output_feed, input_feed)
#     498
#     499         # GreedyDecoder: [batch_size, max_time_step]
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# We also evaluate in the validation set to get a feeling of the performance differences

# %% [markdown]
# # The key evaluation on the test set

# %% [markdown]
# Below is the performance of the model on the unseen dataset

# %%
evaluate_model(training_manager.test_set)
# Out:
# Input text = 'I love Harry Potter..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'man i loved brokeback mountain!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'the people who are worth it know how much i love the da vinci code.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Brokeback Mountain....
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback Mountain was awesome..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Da Vinci Code sucks.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'The Da Vinci Code was awesome in my opinion -- the book and the movie.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'So Brokeback Mountain was really depressing.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Mission Impossible 3 sucked!..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i love kirsten / leah / kate escapades and mission impossible tom as well...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'da vinci code was an awesome movie...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback Mountain sucked..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"I liked the first "" Mission Impossible."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'DA VINCI CODE WAS AWESOME!!!!!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'we're gonna like watch Mission Impossible or Hoot.(
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"Is it just me, or does Harry Potter suck?..."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"Is it just me, or does Harry Potter suck?..."
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i hate Brokeback Mountain!!!!!!!..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i love being a sentry for mission impossible and a station for bonkers.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'da vinci code sucks...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I hated the da vinci code...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'the people who are worth it know how much i love the da vinci code.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback Mountain was boring.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I love Brokeback Mountain.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'friday hung out with kelsie and we went and saw The Da Vinci Code SUCKED!!!!!
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Harry Potter is AWESOME I don't care if anyone says differently!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Stupid brokeback mountain reference i did.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'i love kirsten / leah / kate escapades and mission impossible tom as well...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'da vinci code sucks...
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'DA VINCI CODE IS AWESOME!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback mountain was an awesome movie.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback Mountain sucked.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'dudeee i LOVED brokeback mountain!!!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'The Da Vinci Code is awesome!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'DA VINCI CODE IS AWESOME!!
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Harry Potter is AWESOME I don't care if anyone says differently!..
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Mission Impossible 3 was excellent.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Ok brokeback mountain is such a horrible movie.
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'I did love The Da Vinci Code though.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I have read 1984 and I hate Harry Potter..
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = '"I liked the first "" Mission Impossible."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Brokeback mountain was beautiful...
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'Since Mission Impossible is a piece of crap.
# '
# Dest text = '0
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'I love Harry Potter.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'i heard da vinci code sucked soo much only 2.5 stars:
# '
# Dest text = '0
# '
# Decoded text = '0
# '
#  =======================
# Input text = 'Da vinci code is an awesome book.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = 'the last stand and Mission Impossible 3 both were awesome movies.
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"The Da Vinci Code was awesome, I can't wait to read it..."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"I, too, like Harry Potter.."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================
# Input text = '"He's like,'YEAH I GOT ACNE AND I LOVE BROKEBACK MOUNTAIN '.."
# '
# Dest text = '1
# '
# Decoded text = '1
# '
#  =======================

# %% [markdown]
# Number of corrected decoding =  66564 , out of  88064
# Accuracy = 0.755859375
