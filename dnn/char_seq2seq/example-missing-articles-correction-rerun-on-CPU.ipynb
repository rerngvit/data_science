# %% [markdown]
# # Language correction - missing articles
#
# This notebook demonstrates a working example of applying the character-level sequence-to-sequence with attention model to address a language correction problem. We limit the scope of the problem to fixing a single missing article (a, an, the). This means that given an input text with an article missing, the model would recommend a language-corrected text as an output.

# %% [markdown]
# In particular, this notebook performs the following. Note that the majority of the codes are separated Python files inside the same folder (data_iterator.py, preprocessor.py, tf_graph.py, and training_manager.py).
# - Initial data investigation to see how the data look like
# - Data preprocessing, i.e., converting from raw data to the format that is ready to be trained by a Tensorflow graph for recurrent network modelling.
# - Splitting the data into three parts 1.) training set, 2.) validation set, and 3.) test set.
# - Specifying the hyperparameter for the training
# - Training a sequence-to-sequence model (with attention) on the training set and evaluate an accuracy metric on the validation set. The training stops when the loss metric on the validation set does not improve (using a simple early stopping method).
# - Saving the training model to files
# - Loading the training model
# - Evaluating the performance of the model qualitatively by using it on some random input data
# - Evaluating the performance of the model quantitatively by using the accuracy metric on the test set

# %% [markdown]
# Before you begin, please execute the following steps
# - Download the dataset archive file (missing_article.tar.gz) from https://github.com/rerngvit/dataset/blob/master/nlp/language_correction/missing_article.tar.gz
# - Extract the dataset to the same folder as this notebook. You expect to have the folder "dataset" after the extraction process

# %%
src_data_path  = "./dataset/source.csv/part-00000-3399e745-6191-479d-b42c-434c9cea1010-c000.csv"
dest_data_path = "./dataset/dest.csv/part-00000-9a59ed8f-769a-4108-b277-7f014af68d7c-c000.csv"

# %% [markdown]
# # First let have a look at how the data look like

# %% [markdown]
# We read out the first 10 lines of the source and destination file

# %%
count = 1
for src_line, dest_line in zip(open(src_data_path), 
                               open(dest_data_path)):
    print(src_line + dest_line)
    print("============")
    if count >= 5:
        break
    count = count + 1
# Out:
# "When he was fifteen , he said he wanted to be messenger ."
# "When he was fifteen, he said he wanted to be a messenger."
#
# ============
# His mother sent him to get comb from his aunt .
# His mother sent him to get a comb from his aunt.
#
# ============
# He climbed on stork as the storks were flying south .
# He climbed on a stork as the storks were flying south.
#
# ============
# The chain emerged from Galati Brothers .
# The chain emerged from the Galati Brothers.
#
# ============
# All pages with template on them are listed here .
# All pages with the template on them are listed here.
#
# ============

# %% [markdown]
# The data represents a fixing of missing an article (at most one mistake) and a minor fixing of puncation.

# %% [markdown]
# # Let begin the training process

# %% [markdown]
# First we specify the folder that will store the trained models and Tensorboard data

# %%
model_base_dir = "./trained_models/remove_articles"

# %% [markdown]
# First let have a look at the devices available for Tensorflow to train.
# You expect to see a GPU on the command below.
# Otherwise, the training process will be even longer than it normally would (15-20X+).

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9107794676342764524]

# %%
import numpy as np
import warnings
import matplotlib.pyplot as plt
import time
import os
import json
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.4.1'

# %%
from preprocessor import CharacterLevelSeq2SeqPreprocessor

# %%
lang_data_preprocessor = CharacterLevelSeq2SeqPreprocessor(src_data_path=src_data_path, 
               dest_data_path=dest_data_path, 
               max_number_of_samples=-1)
# Out:
#  Processing in total 440450 lines

# %% [markdown]
# Below is the hyper parameters used for the model

# %%
config = { 'hidden_units' : 256,
           'depth'     : 12,
           'attention_type' : 'Bahdanau',
           'use_embedding' :  True,
           'embedding_size' : 128,
           'num_encoder_symbols' : lang_data_preprocessor.num_src_tokens,
           'num_decoder_symbols' : lang_data_preprocessor.num_dest_tokens,
           'use_residual' : True,
           'attn_input_feeding': True,
           'use_dropout': True,
           'dropout_rate' : 0.02,
           'learning_rate' : 0.0005,
           'max_gradient_norm' : 1.0,
           'batch_size' : 512,
           'num_epochs' : 20,
           'optimizer'  : 'adam',
           'use_fp16'   : False,
           'max_src_seq_length'  : lang_data_preprocessor.max_src_seq_length,
           'max_dest_seq_length' : lang_data_preprocessor.max_dest_seq_length,
           'max_decode_step' : lang_data_preprocessor.max_dest_seq_length,
           'padding_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.PADDED_character],
           'dest_start_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.SEQ_START_CHARACTER],
           'dest_eos_token_index' : lang_data_preprocessor.dest_token_index[
                                       lang_data_preprocessor.EOS_character],
           'model_base_dir': model_base_dir,
           'model_saved_path' : model_base_dir + "/trained_model",
           'use_beamsearch_decode' : False,
           'beam_width' : 64,          
           'saving_last_model' : True,
           'default_device' : '/gpu:0',
           'run_full_trace': False
         }

# %%
from tf_graph import CharacterSeq2SeqModel
from data_iterator import DataFeedIterator
from training_manager import TrainingManager

# %%
training_manager = TrainingManager(lang_data_preprocessor=lang_data_preprocessor,
                                   src_data_path=src_data_path, 
                                   dest_data_path=dest_data_path, 
                                   batch_size=config["batch_size"])

# %%
import json
os.makedirs(model_base_dir, exist_ok=True)
cfg_file_path = model_base_dir + "/config.json"
with open(cfg_file_path, 'w') as file:
     file.write(json.dumps(config))

# %% [markdown]
# # The code below will start the training process
# * Note that it is expected to take around 15-20 hours for a single run (with a GPU). If you do not have a GPU, it can take even longer than that.
# * After the training process is finished. The model would be saved to a file

# %%
#training_manager.fit_eval_dnn(config=config)

# %% [markdown]
# # Loading the trained model from the saved file

# %%
import json

# %%
loaded_config = json.load(open(cfg_file_path))
loaded_config
# Out:
# {'attention_type': 'Bahdanau',
#  'attn_input_feeding': True,
#  'batch_size': 512,
#  'beam_width': 64,
#  'default_device': '/gpu:0',
#  'depth': 12,
#  'dest_eos_token_index': 1,
#  'dest_start_token_index': 2,
#  'dropout_rate': 0.02,
#  'embedding_size': 128,
#  'hidden_units': 256,
#  'learning_rate': 0.0005,
#  'max_decode_step': 51,
#  'max_dest_seq_length': 51,
#  'max_gradient_norm': 1.0,
#  'max_src_seq_length': 50,
#  'model_base_dir': './trained_models/remove_articles',
#  'model_saved_path': './trained_models/remove_articles/trained_model',
#  'num_decoder_symbols': 102,
#  'num_encoder_symbols': 98,
#  'num_epochs': 20,
#  'optimizer': 'adam',
#  'padding_token_index': 0,
#  'run_full_trace': False,
#  'saving_last_model': True,
#  'use_beamsearch_decode': False,
#  'use_dropout': True,
#  'use_embedding': True,
#  'use_fp16': False,
#  'use_residual': True}

# %%
decoding_config = {
    'beam_width': 100,
    'use_beamsearch_decode' : True,
    'max_decode_step': lang_data_preprocessor.max_dest_seq_length,
    'write_n_best' : True,
    'log_device_placement' : True,
    'batch_size': 1,
    'default_device' : '/cpu:0'
    
}

# %%
for k, v in loaded_config.items():
    if k not in decoding_config.keys():
        decoding_config[k] = v

# %%
decoding_config
# Out:
# {'attention_type': 'Bahdanau',
#  'attn_input_feeding': True,
#  'batch_size': 1,
#  'beam_width': 100,
#  'default_device': '/cpu:0',
#  'depth': 12,
#  'dest_eos_token_index': 1,
#  'dest_start_token_index': 2,
#  'dropout_rate': 0.02,
#  'embedding_size': 128,
#  'hidden_units': 256,
#  'learning_rate': 0.0005,
#  'log_device_placement': True,
#  'max_decode_step': 51,
#  'max_dest_seq_length': 51,
#  'max_gradient_norm': 1.0,
#  'max_src_seq_length': 50,
#  'model_base_dir': './trained_models/remove_articles',
#  'model_saved_path': './trained_models/remove_articles/trained_model',
#  'num_decoder_symbols': 102,
#  'num_encoder_symbols': 98,
#  'num_epochs': 20,
#  'optimizer': 'adam',
#  'padding_token_index': 0,
#  'run_full_trace': False,
#  'saving_last_model': True,
#  'use_beamsearch_decode': True,
#  'use_dropout': True,
#  'use_embedding': True,
#  'use_fp16': False,
#  'use_residual': True,
#  'write_n_best': True}

# %%
import tensorflow as tf
tf.reset_default_graph() # to clean out all the variables to allow for rerunning the model
sess = tf.Session(config=tf.ConfigProto(
      allow_soft_placement=True))

# %%
# Start the model
decoding_model = CharacterSeq2SeqModel(session=sess,
                              config=decoding_config, 
                              mode='decode')
# Restoring model parameters
decoding_model.restore(sess, decoding_config["model_saved_path"])
# Out:
#  Setting default device to  /cpu:0
# building model..
# building encoder..
# building decoder and attention..
# use beamsearch decoding..
#  Initial state for decoder cell batch size is  100
# building beamsearch decoder..
# INFO:tensorflow:Restoring parameters from ./trained_models/remove_articles/trained_model
# model restored from ./trained_models/remove_articles/trained_model

# %% [markdown]
# # Evaluating the model qualitatively with unseen data

# %%
def language_correction_text(input_text):
    return training_manager.seq2seq_execution(
    sess, decoding_model, decoding_config['batch_size'], 
    input_text=input_text)

# %%
language_correction_text("I run with table.")
# Out:
# 'I run with the table..\n'

# %%
language_correction_text("I have car.")
# Out:
# 'I have a car...\n'

# %%
language_correction_text("We work in office.")
# Out:
# 'We work in the office.\n'

# %%
language_correction_text("I like to walk with stick.")
# Out:
# 'I like to walk with the stick.\n'

# %%
language_correction_text("This is test.")
# Out:
# 'This is a test. test.\n'

# %%
language_correction_text("I like to travel with car.")
# Out:
# 'I like to travel with the car...\n'

# %%
language_correction_text("I am not sure I like apple.")
# Out:
# 'I am not sure I like the apple.\n'

# %%
language_correction_text("She like to watch movie.")
# Out:
# 'She like to watch the movie.\n'

# %%
language_correction_text("We go to theater.")
# Out:
# 'We go to the theater..\n'

# %%
language_correction_text("This is cat.")
# Out:
# 'This is a cat..\n'

# %%
language_correction_text("I would like to have homerun.")
# Out:
# 'I would like to have a homerun.\n'

# %% [markdown]
# # Evaluating the model quantitatively on the test set

# %% [markdown]
# The code below simply retrieve the data as a batch and using the model to generate the predictions (decoded_text)
# and compare with the ground truth (dest text). At the end of the evaluation, the code would output the accuracy metric, which is the fraction of samples that are matched between the ground truth and the predictions.

# %%
def evaluate_model(dataset):
    num_samples, num_corrected = 0, 0
    
    for source, source_len, dest, dest_len in dataset:
        for sample_idx in range(config['batch_size']):
            beam_idx = 0
            decoding_src_seq  = source[sample_idx, :]
            decoding_dest_seq = dest[sample_idx, :]
            
            input_text = lang_data_preprocessor.src_seq_to_text(decoding_src_seq)
            predicted_text = language_correction_text(input_text)
            actual_text = lang_data_preprocessor.dest_seq_to_text(
                decoding_dest_seq)[1:]   # Ignoring the first SEQ_START chracter
            
            print("Input text = '%s'"     % input_text)
            print("Dest text = '%s'"     %  actual_text)
            print("Decoded text = '%s'  " % predicted_text)
            print(" =======================")
            
            if actual_text.strip() == predicted_text.strip():
                num_corrected += 1
            
            num_samples += 1
    
    print(" Number of corrected decoding = ", num_corrected, ", out of ", num_samples)
    accuracy = (num_corrected + 0.0) / num_samples
    print(" Accuracy = %s " % accuracy)

# %%
train_data_list = list(training_manager.train_set)
train_data_list
# Out:
# [(array([[51., 72., 85., ...,  0.,  0.,  0.],
#          [43., 72.,  3., ...,  0.,  0.,  0.],
#          [87., 75., 76., ...,  0.,  0.,  0.],
#          ...,
#          [55., 75., 72., ...,  0.,  0.,  0.],
#          [45., 72., 85., ...,  0.,  0.,  0.],
#          [ 6.,  3., 58., ...,  0.,  0.,  0.]]),
#   array([31, 35, 44, 41, 35, 26, 42, 45, 31, 44, 36, 34, 34, 47, 40, 41, 34,
#          44, 46, 45, 48, 49, 47, 45, 35, 42, 40, 36, 47, 39, 46, 43, 42, 34,
#          42, 48, 30, 22, 41, 30, 34, 47, 41, 44, 38, 45, 44, 34, 44, 41, 40,
#          42, 35, 32, 40, 42, 32, 35, 48, 33, 45, 31, 43, 42, 28, 44, 42, 45,
#          39, 37, 41, 33, 45, 37, 44, 46, 42, 33, 43, 34, 33, 44, 44, 31, 48,
#          46, 26, 35, 40, 32, 40, 46, 34, 34, 31, 38, 37, 41, 41, 39, 49, 39,
#          31, 47, 41, 45, 45, 44, 43, 22, 34, 44, 35, 43, 40, 44, 45, 42, 40,
#          40, 46, 48, 19, 41, 44, 38, 38, 40, 28, 43, 41, 36, 43, 40, 37, 39,
#          44, 34, 34, 27, 45, 35, 48, 27, 40, 40, 27, 43, 39, 43, 41, 34, 40,
#          46, 39, 44, 41, 41, 46, 48, 34, 37, 33, 46, 29, 29, 45, 44, 47, 33,
#          34, 49, 23, 48, 46, 44, 44, 50, 44, 43, 40, 40, 41, 34, 42, 36, 47,
#          44, 42, 39, 41, 43, 47, 47, 43, 42, 37, 41, 34, 45, 38, 48, 42, 28,
#          39, 46, 45, 33, 47, 36, 47, 44, 39, 45, 34, 43, 46, 31, 47, 37, 49,
#          43, 27, 37, 21, 30, 46, 39, 43, 47, 42, 40, 40, 47, 40, 30, 29, 35,
#          48, 35, 41, 34, 34, 24, 31, 47, 30, 24, 48, 46, 45, 45, 36, 30, 30,
#          43, 49, 34, 40, 47, 41, 45, 46, 45, 47, 48, 47, 37, 43, 32, 43, 41,
#          49, 51, 49, 50, 49, 46, 38, 38, 47, 48, 47, 50, 46, 45, 48, 46, 47,
#          44, 38, 39, 50, 34, 48, 47, 51, 51, 28, 47, 39, 35, 41, 40, 48, 34,
#          36, 41, 35, 51, 46, 38, 42, 33, 51, 39, 51, 51, 44, 50, 19, 22, 44,
#          42, 45, 38, 27, 41, 36, 42, 43, 48, 46, 50, 46, 42, 51, 38, 49, 49,
#          43, 34, 44, 44, 47, 42, 47, 45, 51, 38, 48, 39, 46, 48, 46, 48, 46,
#          45, 50, 38, 48, 43, 44, 25, 47, 50, 33, 50, 26, 37, 40, 49, 40, 38,
#          36, 24, 21, 46, 35, 47, 37, 46, 35, 46, 37, 40, 40, 44, 42, 48, 51,
#          51, 43, 33, 43, 49, 38, 44, 51, 42, 39, 45, 51, 44, 34, 44, 36, 51,
#          48, 33, 29, 49, 49, 50, 49, 49, 47, 38, 44, 51, 49, 42, 45, 48, 40,
#          43, 48, 50, 45, 46, 51, 42, 48, 36, 40, 49, 49, 30, 45, 49, 25, 47,
#          30, 39, 38, 45, 49, 46, 43, 48, 49, 46, 35, 38, 48, 38, 49, 48, 49,
#          48, 51, 38, 45, 43, 51, 51, 45, 31, 43, 51, 29, 43, 46, 41, 38, 48,
#          44, 50, 46, 38, 46, 42, 50, 40, 50, 46, 39, 40, 38, 44, 42, 48, 35,
#          44, 47, 48, 48, 47, 49, 43, 42, 43, 44, 50, 30, 50, 44, 51, 36, 20,
#          51, 33, 49, 51, 49, 47, 48, 49, 46, 48, 42, 51, 45, 44, 44, 33, 47,
#          38, 31, 51, 49, 42, 26, 36, 40, 40, 48, 46, 36, 48, 27, 42, 44, 49,
#          33, 42, 46, 38, 48, 47, 51, 48, 41, 45, 43, 42, 39, 44, 38, 44, 23,
#          46, 46, 49, 38, 35, 49, 33, 45, 35, 38, 47, 38, 46, 33, 47, 38, 46,
#          38, 50, 36, 48, 47, 51, 45, 48, 50, 49, 44, 50, 48, 34, 44, 49, 47,
#          45, 47, 49, 35, 37, 36, 44, 36, 38, 51, 43, 38, 42, 47, 42, 23, 50,
#          50, 51, 50, 37, 50, 41, 46, 48, 44, 43, 48, 44, 45, 38, 34, 48, 46,
#          49, 51, 44, 37, 41, 40, 42, 44, 42, 42, 50, 51, 36, 44, 44, 45, 38,
#          34, 44, 38, 41, 48, 41, 26, 44, 38, 36, 36, 42, 38, 51, 22, 50, 44,
#          49, 48, 51, 44, 51, 46, 51, 45, 42, 46, 51, 48, 44, 47, 43, 25, 41,
#          46, 44, 38, 48, 51, 51, 49, 51, 48, 35, 37, 44, 38, 36, 44, 48, 47,
#          35, 46, 47, 47, 49, 51, 51, 42, 47, 46, 49, 29, 51, 34, 21, 43, 32,
#          43, 47]))]

# %%
import random

# %% [markdown]
# First, let evaluate the performance on the training set. We do data sampling here with *k* representing the number of batches to obtain early results before progressing to larger *k*

# %%
evaluate_model(random.sample(train_data_list, k=2))
# Out:
# Input text = '*There were 39 RVs during ceasefire period .
# '
# Dest text = '*There were 39 RVs during the ceasefire period.
# '
# Decoded text = '*There were 39 RVs during the ceasefire period.
# '
#  =======================
# Input text = 'Several condo towers are located along beach .
# '
# Dest text = 'Several condo towers are located along the beach.
# '
# Decoded text = 'Several condo towers are located along the beach.
# '
#  =======================
# Input text = 'The median age in city was 44 years .
# '
# Dest text = 'The median age in the city was 44 years.
# '
# Decoded text = 'The median age in the city was 44 years.
# '
#  =======================
# Input text = 'Terry Labonte won pole .
# '
# Dest text = 'Terry Labonte won the pole.
# '
# Decoded text = 'Terry Labonte won the pole.
# '
#  =======================
# Input text = '[ [ File : Steven Wright-I Have Pony.jpg ] ]
# '
# Dest text = '[[File:Steven Wright-I Have a Pony.jpg]]
# '
# Decoded text = '[[File:Steven Wright-I Have a Pony.jpg]]
# '
#  =======================
# Input text = 'He died next year at age of 67 .
# '
# Dest text = 'He died the next year at the age of 67.
# '
# Decoded text = 'He died the next year at the age of 67.
# '
#  =======================
# Input text = 'In February 1844 case went to trial .
# '
# Dest text = 'In February 1844 the case went to trial.
# '
# Decoded text = 'In February 1844 the case went to the trial.
# '
#  =======================
# Input text = '"Eventually , Kemper shot her in head ."
# '
# Dest text = '"Eventually, Kemper shot her in the head."
# '
# Decoded text = '"Eventually, Kemper shot her in the head."
# '
#  =======================
# Input text = 'It was n't ripped from website ! ?
# '
# Dest text = 'It wasn't ripped from a website!?
# '
# Decoded text = 'It wasn't ripped from the website!?
# '
#  =======================
# Input text = 'Stations in bold are current termini .
# '
# Dest text = 'Stations in bold are the current termini.
# '
# Decoded text = 'Stations in the bold are current termini.
# '
#  =======================
# Input text = '"The per capita income for town was $ 16,744 ."
# '
# Dest text = '"The per capita income for the town was $16,744."
# '
# Decoded text = '"The per capita income for the town was $16,744."
# '
#  =======================
# Input text = 'The result of debate was speedily deleted .
# '
# Dest text = 'The result of the debate was speedily deleted.
# '
# Decoded text = 'The result of the debate was speedily deleted.
# '
#  =======================
# Input text = 'Her main fighter was A6M2 Reisen .
# '
# Dest text = 'Her main fighter was the A6M2 Reisen.
# '
# Decoded text = 'Her main fighter was the A6M2 Reisen.
# '
#  =======================
# Input text = 'I have n't seen sequel .
# '
# Dest text = 'I haven't seen the sequel.
# '
# Decoded text = 'I haven't seen a sequel.
# '
#  =======================
# Input text = 'She used crow bar for murder weapon .
# '
# Dest text = 'She used a crow bar for a murder weapon.
# '
# Decoded text = 'She used a crow bar for murder weapon.
# '
#  =======================
# Input text = 'The housemates passed task .
# '
# Dest text = 'The housemates passed the task.
# '
# Decoded text = 'The housemates passed the task.
# '
#  =======================
# Input text = 'I took ( unsupported ) cat off Trani .
# '
# Dest text = 'I took the (unsupported) cat off Trani.
# '
# Decoded text = 'I took the (unsupported) cat off Trani.
# '
#  =======================
# Input text = 'The tip of tail was white .
# '
# Dest text = 'The tip of the tail was white.
# '
# Decoded text = 'The tip of the tail was white.
# '
#  =======================
# Input text = 'It was worth wait .
# '
# Dest text = 'It was worth the wait.
# '
# Decoded text = 'It was a worth wait.
# '
#  =======================
# Input text = 'The population was 303 at 2010 census .
# '
# Dest text = 'The population was 303 at the 2010 census.
# '
# Decoded text = 'The population was 303 at the 2010 census.
# '
#  =======================
# Input text = 'Voltaire 's view on Bible was negative .
# '
# Dest text = 'Voltaire's view on the Bible was negative.
# '
# Decoded text = 'Voltaire's view on the Bible was negative.
# '
#  =======================
# Input text = 'Villagers do fishing in lake .
# '
# Dest text = 'Villagers do fishing in the lake.
# '
# Decoded text = 'Villagers do fishing in the lake.
# '
#  =======================
# Input text = ': : : That 's best thing I 've heard today !
# '
# Dest text = ':::That's the best thing I've heard today!
# '
# Decoded text = ':::That's the best thing I've heard today!
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'It peaked at number 36 on U.S .
# '
# Dest text = 'It peaked at number 36 on the U.S.
# '
# Decoded text = 'It peaked at number 36 on the U.S.
# '
#  =======================
# Input text = 'I think redirect would not be appropriate .
# '
# Dest text = 'I think a redirect would not be appropriate.
# '
# Decoded text = 'I think a redirect would not be appropriate.
# '
#  =======================
# Input text = 'Collins admitted abuse in 1993 .
# '
# Dest text = 'Collins admitted the abuse in 1993.
# '
# Decoded text = 'Collins admitted the abuse in 1993.
# '
#  =======================
# Input text = '"Near me , men were collapsing in dirty snow ."
# '
# Dest text = '"Near me, men were collapsing in the dirty snow."
# '
# Decoded text = '"Near me, men were collapsing in the dirty snow."
# '
#  =======================
# Input text = '"The per capita income for town was $ 45,495 ."
# '
# Dest text = '"The per capita income for the town was $45,495."
# '
# Decoded text = '"The per capita income for the town was $45,495."
# '
#  =======================
# Input text = '"* Freed.in , FOSS event held in India"
# '
# Dest text = '"* Freed.in, an FOSS event held in India"
# '
# Decoded text = '"* Freed.in, the FOSS event held in India"
# '
#  =======================
# Input text = 'Grant joined his army in field on March 17 .
# '
# Dest text = 'Grant joined his army in the field on March 17.
# '
# Decoded text = 'Grant joined his army in the field on March 17.
# '
#  =======================
# Input text = 'He was member of Methodist church .
# '
# Dest text = 'He was a member of the Methodist church.
# '
# Decoded text = 'He was a member of the Methodist church.
# '
#  =======================
# Input text = 'I was building fence for our horse paddock .
# '
# Dest text = 'I was building a fence for our horse paddock.
# '
# Decoded text = 'I was building a fence for our horse paddock.
# '
#  =======================
# Input text = 'He became friend of J .
# '
# Dest text = 'He became a friend of J.
# '
# Decoded text = 'He became a friend of J.
# '
#  =======================
# Input text = 'Abel raised army to punish them .
# '
# Dest text = 'Abel raised an army to punish them.
# '
# Decoded text = 'Abel raised the army to punish them.
# '
#  =======================
# Input text = '( She went on to win election . )
# '
# Dest text = '(She went on to win the election.)
# '
# Decoded text = '(She went on to win the election.)
# '
#  =======================
# Input text = 'It never became national priority .
# '
# Dest text = 'It never became a national priority.
# '
# Decoded text = 'It never became a national priority.
# '
#  =======================
# Input text = 'Shiva refused to grant such boon .
# '
# Dest text = 'Shiva refused to grant such a boon.
# '
# Decoded text = 'Shiva refused to grant such a boon.
# '
#  =======================
# Input text = '"The population was 2,001 at 2010 census ."
# '
# Dest text = '"The population was 2,001 at the 2010 census."
# '
# Decoded text = '"The population was 2,001 at the 2010 census."
# '
#  =======================
# Input text = 'This happened third day as well .
# '
# Dest text = 'This happened the third day as well.
# '
# Decoded text = 'This happened the third day as well.
# '
#  =======================
# Input text = 'It was major victory for union .
# '
# Dest text = 'It was a major victory for the union.
# '
# Decoded text = 'It was a major victory for the union.
# '
#  =======================
# Input text = 'It took maybe half hour .
# '
# Dest text = 'It took maybe half an hour.
# '
# Decoded text = 'It took maybe half an hour.
# '
#  =======================
# Input text = 'The Giants win pennant !
# '
# Dest text = 'The Giants win the pennant!
# '
# Decoded text = 'The Giants win the pennant!
# '
#  =======================
# Input text = 'Speedy Keep is stupidest vote I 've seen .
# '
# Dest text = 'Speedy Keep is the stupidest vote I've seen.
# '
# Decoded text = 'Speedy Keep is a stupidest vote I've seen.
# '
#  =======================
# Input text = 'He was national selector from 1907 to 1914 .
# '
# Dest text = 'He was a national selector from 1907 to 1914.
# '
# Decoded text = 'He was a national selector from 1907 to 1914.
# '
#  =======================
# Input text = 'Please now follow link back to .
# '
# Dest text = 'Please now follow the link back to .
# '
# Decoded text = 'Please now follow the link back to .
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'It was band 's only album for major label .
# '
# Dest text = 'It was the band's only album for a major label.
# '
# Decoded text = 'It was the band's only album for the major label.
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'It was written in 6th-century .
# '
# Dest text = 'It was written in the 6th-century.
# '
# Decoded text = 'It was written in the 6th-century.
# '
#  =======================
# Input text = 'CTQs reflect expressed needs of customer .
# '
# Dest text = 'CTQs reflect the expressed needs of the customer.
# '
# Decoded text = 'CTQs reflect expressed needs of the customer.
# '
#  =======================
# Input text = 'He was later acquitted in second trial in 1970 .
# '
# Dest text = 'He was later acquitted in a second trial in 1970.
# '
# Decoded text = 'He was later acquitted in the second trial in 1970.He was later acquitted in a second trial in 1970.
# '
#  =======================
# Input text = 'Hughes : The destruction was punishment .
# '
# Dest text = 'Hughes: The destruction was a punishment.
# '
# Decoded text = 'Hughes: The destruction was the punishment.
# '
#  =======================
# Input text = 'But now mind was set on clear vocalist .
# '
# Dest text = 'But now the mind was set on a clear vocalist.
# '
# Decoded text = 'But now mind was set on a clear vocalist.
# '
#  =======================
# Input text = 'Bean was avid hunter and fisherman .
# '
# Dest text = 'Bean was an avid hunter and fisherman.
# '
# Decoded text = 'Bean was an avid hunter and fisherman.
# '
#  =======================
# Input text = 'People also used fort as fur trading post .
# '
# Dest text = 'People also used the fort as a fur trading post.
# '
# Decoded text = 'People also used fort as a fur trading post.
# '
#  =======================
# Input text = 'There was also armored regiment of 55 tanks .
# '
# Dest text = 'There was also an armored regiment of 55 tanks.
# '
# Decoded text = 'There was also an armored regiment of 55 tanks.
# '
#  =======================
# Input text = 'The result of debate was ambiguous .
# '
# Dest text = 'The result of the debate was ambiguous.
# '
# Decoded text = 'The result of the debate was ambiguous.
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = ': The result of discussion was : rename .
# '
# Dest text = ':The result of the discussion was: rename.
# '
# Decoded text = ':The result of the discussion was: rename.
# '
#  =======================
# Input text = 'The population was 182 at 2010 census .
# '
# Dest text = 'The population was 182 at the 2010 census.
# '
# Decoded text = 'The population was 182 at the 2010 census.
# '
#  =======================
# Input text = 'Arrows give sense of motion .
# '
# Dest text = 'Arrows give the sense of motion.
# '
# Decoded text = 'Arrows give the sense of the motion.
# '
#  =======================
# Input text = 'Steenhuis also won award in 2004 .
# '
# Dest text = 'Steenhuis also won the award in 2004.
# '
# Decoded text = 'Steenhuis also won the award in 2004.
# '
#  =======================
# Input text = 'I do n't find such category existing .
# '
# Dest text = 'I don't find such a category existing.
# '
# Decoded text = 'I don't find such a category existing.
# '
#  =======================
# Input text = 'He studied law and was admitted to bar .
# '
# Dest text = 'He studied law and was admitted to the bar.
# '
# Decoded text = 'He studied law and was admitted to the bar.
# '
#  =======================
# Input text = 'The movement used was manual wind Valjoux cal .
# '
# Dest text = 'The movement used was a manual wind Valjoux cal.
# '
# Decoded text = 'The movement used was a manual wind Valjoux cal.
# '
#  =======================
# Input text = 'The result of debate was delete ( pending ) .
# '
# Dest text = 'The result of the debate was delete (pending).
# '
# Decoded text = 'The result of the debate was delete (pending).
# '
#  =======================
# Input text = 'The compilation reached number 74 in U.S .
# '
# Dest text = 'The compilation reached number 74 in the U.S.
# '
# Decoded text = 'The compilation reached number 74 in the U.S.
# '
#  =======================
# Input text = 'His .441 on-base percentage led league .
# '
# Dest text = 'His .441 on-base percentage led the league.
# '
# Decoded text = 'His .441 on-base percentage led the league.
# '
#  =======================
# Input text = ': # Several users find article interesting .
# '
# Dest text = ':#Several users find the article interesting.
# '
# Decoded text = ':#Several users find the article interesting.
# '
#  =======================
# Input text = 'The ruby was hidden in underground cave .
# '
# Dest text = 'The ruby was hidden in an underground cave.
# '
# Decoded text = 'The ruby was hidden in the underground cave.
# '
#  =======================
# Input text = 'Consequently we get section s'i on U'i .
# '
# Dest text = 'Consequently we get a section s'i on U'i.
# '
# Decoded text = 'Consequently we get a section s'i on the U'i.
# '
#  =======================
# Input text = 'This was last transmission from Flight 933 .
# '
# Dest text = 'This was the last transmission from Flight 933.
# '
# Decoded text = 'This was the last transmission from Flight 933.
# '
#  =======================
# Input text = 'I would n't mind if other side did same .
# '
# Dest text = 'I wouldn't mind if the other side did the same.
# '
# Decoded text = 'I wouldn't mind if the other side did the same.
# '
#  =======================
# Input text = 'Outdoor showers are provided throughout site .
# '
# Dest text = 'Outdoor showers are provided throughout the site.
# '
# Decoded text = 'Outdoor showers are provided throughout the site.
# '
#  =======================
# Input text = 'At 2000 census the population was 108 .
# '
# Dest text = 'At the 2000 census the population was 108.
# '
# Decoded text = 'At the 2000 census the population was 108.
# '
#  =======================
# Input text = '"In US , song peaked at No ."
# '
# Dest text = '"In the US, the song peaked at No."
# '
# Decoded text = '"In the US, song peaked at No."
# '
#  =======================
# Input text = '* Batman 's first aircraft was autogyro .
# '
# Dest text = '* Batman's first aircraft was an autogyro.
# '
# Decoded text = '* Batman's first aircraft was an autogyro.
# '
#  =======================
# Input text = 'I wanted to have 100th support .
# '
# Dest text = 'I wanted to have the 100th support.
# '
# Decoded text = 'I wanted to have the 100th support.
# '
#  =======================
# Input text = 'At ten he entered Milan Conservatory .
# '
# Dest text = 'At ten he entered the Milan Conservatory.
# '
# Decoded text = 'At ten he entered the Milan Conservatory.
# '
#  =======================
# Input text = 'The unknowns are velocity and pressure .
# '
# Dest text = 'The unknowns are the velocity and the pressure .
# '
# Decoded text = 'The unknowns are a velocity and pressure.
# '
#  =======================
# Input text = '"In 2005 , he sold club to Silk Way Airlines ."
# '
# Dest text = '"In 2005, he sold the club to Silk Way Airlines."
# '
# Decoded text = '"In 2005, he sold the club to Silk Way Airlines."
# '
#  =======================
# Input text = 'She had second marriage to Sir Richard Dayrell .
# '
# Dest text = 'She had a second marriage to Sir Richard Dayrell.
# '
# Decoded text = 'She had a second marriage to Sir Richard Dayrell.
# '
#  =======================
# Input text = 'The ruling Meargh hold clans together .
# '
# Dest text = 'The ruling Meargh hold the clans together.
# '
# Decoded text = 'The ruling Meargh hold the clans together.
# '
#  =======================
# Input text = '"^ For sun 's size , see Miller , Edward ."
# '
# Dest text = '"^ For the sun's size, see Miller, Edward."
# '
# Decoded text = '"^ For the sun's size, see Miller, Edward."
# '
#  =======================
# Input text = 'Flanagan left school at age of 16 .
# '
# Dest text = 'Flanagan left school at the age of 16.
# '
# Decoded text = 'Flanagan left the school at the age of 16.
# '
#  =======================
# Input text = '"However , Bagdad was very poor port ."
# '
# Dest text = '"However, Bagdad was a very poor port."
# '
# Decoded text = '"However, Bagdadad was a very poor port."
# '
#  =======================
# Input text = 'The film became box office hit .
# '
# Dest text = 'The film became a box office hit.
# '
# Decoded text = 'The film became a box office hit.
# '
#  =======================
# Input text = 'He says 'I 'm coming in to tak lot . '
# '
# Dest text = 'He says 'I'm coming in to tak the lot.'
# '
# Decoded text = 'He says 'I'm coming in to tak a lot.'
# '
#  =======================
# Input text = 'That was end of my violin career .
# '
# Dest text = 'That was the end of my violin career.
# '
# Decoded text = 'That was the end of my violin career.
# '
#  =======================
# Input text = 'Sent to asylum and escaped .
# '
# Dest text = 'Sent to an asylum and escaped.
# '
# Decoded text = 'Sent to the asylum and escaped.
# '
#  =======================
# Input text = 'This potential future king died as infant .
# '
# Dest text = 'This potential future king died as an infant.
# '
# Decoded text = 'This potential future king died as an infant.
# '
#  =======================
# Input text = '"In addition , there swimming pool was built ."
# '
# Dest text = '"In addition, there a swimming pool was built."
# '
# Decoded text = '"In addition, there a swimming pool was built."
# '
#  =======================
# Input text = 'She came off bench for first 12 games .
# '
# Dest text = 'She came off the bench for the first 12 games.
# '
# Decoded text = 'She came off the bench for the first 12 games.
# '
#  =======================
# Input text = '"*Keep , I removed website spam ."
# '
# Dest text = '"*Keep, I removed the website spam."
# '
# Decoded text = '"*Keep, I removed the website spam."
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 39,802 ."
# '
# Dest text = '"The per capita income for the CDP was $39,802."
# '
# Decoded text = '"The per capita income for the CDP was $39,802."
# '
#  =======================
# Input text = 'Crawford made uncomplicated recovery .
# '
# Dest text = 'Crawford made an uncomplicated recovery.
# '
# Decoded text = 'Crawford made an uncomplicated recovery.
# '
#  =======================
# Input text = '* I drove Mary car .
# '
# Dest text = '* I drove Mary the car.
# '
# Decoded text = '* I drove a Mary car.
# '
#  =======================
# Input text = 'He won championship eight years later .
# '
# Dest text = 'He won the championship eight years later.
# '
# Decoded text = 'He won the championship eight years later.
# '
#  =======================
# Input text = 'He stayed with company for three years .
# '
# Dest text = 'He stayed with the company for three years.
# '
# Decoded text = 'He stayed with the company for three years.
# '
#  =======================
# Input text = 'It was agrahara .
# '
# Dest text = 'It was an agrahara.
# '
# Decoded text = 'It was an agrahara.
# '
#  =======================
# Input text = '"The per capita income for city was $ 16,254 ."
# '
# Dest text = '"The per capita income for the city was $16,254."
# '
# Decoded text = '"The per capita income for the city was $16,254."
# '
#  =======================
# Input text = 'It sent wave of happiness in province .
# '
# Dest text = 'It sent a wave of happiness in the province.
# '
# Decoded text = 'It sent wave of happiness in the province.
# '
#  =======================
# Input text = 'And Beatles are n't even on list .
# '
# Dest text = 'And the Beatles aren't even on the list.
# '
# Decoded text = 'And Beatles aren't even on the list.
# '
#  =======================
# Input text = 'Other authors exaggerate age of Cato .
# '
# Dest text = 'Other authors exaggerate the age of Cato.
# '
# Decoded text = 'Other authors exaggerate the age of Cato.
# '
#  =======================
# Input text = '"The per capita income for city was $ 12,751 ."
# '
# Dest text = '"The per capita income for the city was $12,751."
# '
# Decoded text = '"The per capita income for the city was $12,751."
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'But race itself was a horror for her .
# '
# Dest text = 'But the race itself was a horror for her.
# '
# Decoded text = 'But the race itself was a horror for her.
# '
#  =======================
# Input text = 'Please now follow link back to .
# '
# Dest text = 'Please now follow the link back to .
# '
# Decoded text = 'Please now follow the link back to .
# '
#  =======================
# Input text = 'The population was 152 at 2010 census .
# '
# Dest text = 'The population was 152 at the 2010 census.
# '
# Decoded text = 'The population was 152 at the 2010 census.
# '
#  =======================
# Input text = 'The result of debate was Redirect .
# '
# Dest text = 'The result of the debate was Redirect.
# '
# Decoded text = 'The result of the debate was Redirect.
# '
#  =======================
# Input text = 'Do I get page ?
# '
# Dest text = 'Do I get a page?
# '
# Decoded text = 'Do I get a page?
# '
#  =======================
# Input text = 'There are 73 police stations across state .
# '
# Dest text = 'There are 73 police stations across the state.
# '
# Decoded text = 'There are 73 police stations across the state.
# '
#  =======================
# Input text = 'Dr. Croghan himself died of disease in 1849 .
# '
# Dest text = 'Dr. Croghan himself died of the disease in 1849.
# '
# Decoded text = 'Dr. Croghan himself died of the disease in 1849.
# '
#  =======================
# Input text = 'The population was 429 at 2010 census .
# '
# Dest text = 'The population was 429 at the 2010 census.
# '
# Decoded text = 'The population was 429 at the 2010 census.
# '
#  =======================
# Input text = 'The lid is then opened and product removed .
# '
# Dest text = 'The lid is then opened and the product removed.
# '
# Decoded text = 'The lid is then opened and the product removed.
# '
#  =======================
# Input text = 'I have applied appropriate { { db-bio } } tag .
# '
# Dest text = 'I have applied the appropriate {{db-bio}} tag.
# '
# Decoded text = 'I have applied an appropriate {{db-bio}} tag.
# '
#  =======================
# Input text = 'It was more than just garden railway .
# '
# Dest text = 'It was more than just a garden railway.
# '
# Decoded text = 'It was more than just a garden railway.
# '
#  =======================
# Input text = 'The outcome of battle was uneven tie .
# '
# Dest text = 'The outcome of the battle was an uneven tie.
# '
# Decoded text = 'The outcome of the battle was the uneven tie.
# '
#  =======================
# Input text = 'The result of debate was SPEEDY DELETE .
# '
# Dest text = 'The result of the debate was SPEEDY DELETE.
# '
# Decoded text = 'The result of the debate was SPEEDY DELETE.
# '
#  =======================
# Input text = ': : : :I 've added appropriate sentence to .
# '
# Dest text = '::::I've added an appropriate sentence to .
# '
# Decoded text = '::::I've added the appropriate sentence to .
# '
#  =======================
# Input text = 'He is troubled since day his daughter died .
# '
# Dest text = 'He is troubled since the day his daughter died.
# '
# Decoded text = 'He is troubled since the day his daughter died.
# '
#  =======================
# Input text = 'The result of debate was Delete .
# '
# Dest text = 'The result of the debate was Delete.
# '
# Decoded text = 'The result of the debate was Delete.
# '
#  =======================
# Input text = 'They also have relatively long half-life .
# '
# Dest text = 'They also have a relatively long half-life.
# '
# Decoded text = 'They also have a relatively long half-life.
# '
#  =======================
# Input text = '* In 2002 he was awarded Order of Ontario .
# '
# Dest text = '* In 2002 he was awarded the Order of Ontario.
# '
# Decoded text = '* In 2002 he was awarded the Order of Ontario.
# '
#  =======================
# Input text = 'It was designed and built by couple .
# '
# Dest text = 'It was designed and built by the couple.
# '
# Decoded text = 'It was designed and built by the couple.
# '
#  =======================
# Input text = 'The deceased was buried in earth .
# '
# Dest text = 'The deceased was buried in the earth.
# '
# Decoded text = 'The deceased was buried in the earth.
# '
#  =======================
# Input text = 'Finally troops were forced to open fire .
# '
# Dest text = 'Finally the troops were forced to open fire.
# '
# Decoded text = 'Finally the troops were forced to open fire.
# '
#  =======================
# Input text = 'The result of debate was keep .
# '
# Dest text = 'The result of the debate was keep.
# '
# Decoded text = 'The result of the debate was keep.
# '
#  =======================
# Input text = '"The population was 2,930 at 2010 census ."
# '
# Dest text = '"The population was 2,930 at the 2010 census."
# '
# Decoded text = '"The population was 2,930 at the 2010 census."
# '
#  =======================
# Input text = 'Won became professional in 1998 .
# '
# Dest text = 'Won became a professional in 1998.
# '
# Decoded text = 'Won became a professional in 1998.
# '
#  =======================
# Input text = 'They have not released series to home video .
# '
# Dest text = 'They have not released the series to home video.
# '
# Decoded text = 'They have not released a series to home video.
# '
#  =======================
# Input text = 'Blistex began as small family company in 1947 .
# '
# Dest text = 'Blistex began as a small family company in 1947.
# '
# Decoded text = 'Blistex began as a small family company in 1947.
# '
#  =======================
# Input text = 'Rumours have no place in encyclopedia .
# '
# Dest text = 'Rumours have no place in an encyclopedia.
# '
# Decoded text = 'Rumours have no place in the encyclopedia.
# '
#  =======================
# Input text = 'Could you detail your problem little more ?
# '
# Dest text = 'Could you detail your problem a little more?
# '
# Decoded text = 'Could you detail your problem a little more?
# '
#  =======================
# Input text = '**Gzornenplatz 's words are bit strong .
# '
# Dest text = '**Gzornenplatz's words are a bit strong.
# '
# Decoded text = '**Gzornenplatz's words are a bit strong.
# '
#  =======================
# Input text = 'They have two sons and daughter .
# '
# Dest text = 'They have two sons and a daughter.
# '
# Decoded text = 'They have two sons and a daughter.
# '
#  =======================
# Input text = 'I am going to turn this into redirect .
# '
# Dest text = 'I am going to turn this into a redirect.
# '
# Decoded text = 'I am going to turn this into a redirect.
# '
#  =======================
# Input text = 'The Ione Miwok elected tribal council in 1996 .
# '
# Dest text = 'The Ione Miwok elected a tribal council in 1996.
# '
# Decoded text = 'The Ione Miwok elected a tribal council in 1996.
# '
#  =======================
# Input text = 'They eventually settled in area around 450 .
# '
# Dest text = 'They eventually settled in the area around 450.
# '
# Decoded text = 'They eventually settled in the area around 450.
# '
#  =======================
# Input text = 'The result of debate was Delete .
# '
# Dest text = 'The result of the debate was Delete.
# '
# Decoded text = 'The result of the debate was Delete.
# '
#  =======================
# Input text = '"In 1943 , destroyer was named in his honor ."
# '
# Dest text = '"In 1943, the destroyer was named in his honor."
# '
# Decoded text = '"In 1943, the destroyer was named in his honor."
# '
#  =======================
# Input text = 'He was appointed flight commander with No .
# '
# Dest text = 'He was appointed a flight commander with No.
# '
# Decoded text = 'He was appointed a flight commander with No.
# '
#  =======================
# Input text = '"It had share capital of 50,000 pounds ."
# '
# Dest text = '"It had a share capital of 50,000 pounds."
# '
# Decoded text = '"It had a share capital of 50,000 pounds."
# '
#  =======================
# Input text = 'The Act had number of purposes .
# '
# Dest text = 'The Act had a number of purposes.
# '
# Decoded text = 'The Act had a number of purposes.
# '
#  =======================
# Input text = 'He hosted radio show Sommartoppen in 1996 .
# '
# Dest text = 'He hosted the radio show Sommartoppen in 1996.
# '
# Decoded text = 'He hosted a radio show Sommartoppen in 1996.
# '
#  =======================
# Input text = ': # Noting the use of term isolated instances .
# '
# Dest text = ':# Noting the use of the term isolated instances.
# '
# Decoded text = ':#Noting the use of a term isolated instances.
# '
#  =======================
# Input text = '", Lumino had unemployment rate of 2.27 % ."
# '
# Dest text = '", Lumino had an unemployment rate of 2.27%."
# '
# Decoded text = '", Lumino had an unemployment rate of 2.27%."
# '
#  =======================
# Input text = 'Two music videos were shot to promote song .
# '
# Dest text = 'Two music videos were shot to promote the song.
# '
# Decoded text = 'Two music videos were shot to promote the song.
# '
#  =======================
# Input text = '"In ways , mall was new downtown ."
# '
# Dest text = '"In ways, the mall was a new downtown."
# '
# Decoded text = '"In ways, the mall was new downtown."
# '
#  =======================
# Input text = 'The ions are extracted through exit cathode .
# '
# Dest text = 'The ions are extracted through the exit cathode.
# '
# Decoded text = 'The ions are extracted through the exit cathode.
# '
#  =======================
# Input text = 'I move for immediate removal of AfD tag .
# '
# Dest text = 'I move for the immediate removal of the AfD tag.
# '
# Decoded text = 'I move for an immediate removal of the AfD tag.
# '
#  =======================
# Input text = 'Also hosted cooking-show Musta Pippuri .
# '
# Dest text = 'Also hosted a cooking-show Musta Pippuri.
# '
# Decoded text = 'Also hosted the cooking-show Musta Pippuri.
# '
#  =======================
# Input text = 'The 1921 census recorded population as 233 .
# '
# Dest text = 'The 1921 census recorded the population as 233.
# '
# Decoded text = 'The 1921 census recorded the population as 233.
# '
#  =======================
# Input text = 'He was carried in triumph at finish .
# '
# Dest text = 'He was carried in triumph at the finish.
# '
# Decoded text = 'He was carried in a triumph at finish.
# '
#  =======================
# Input text = 'Watts was forward line player .
# '
# Dest text = 'Watts was a forward line player.
# '
# Decoded text = 'Watts was a forward line player.
# '
#  =======================
# Input text = 'I did n't think it was difficult transition .
# '
# Dest text = 'I didn't think it was a difficult transition.
# '
# Decoded text = 'I didn't think it was a difficult transition.
# '
#  =======================
# Input text = 'he soon became member of Nation of Islam .
# '
# Dest text = 'he soon became a member of the Nation of Islam.
# '
# Decoded text = 'he soon became a member of the Nation of Islam.
# '
#  =======================
# Input text = 'He served 8 day suspension for the incident .
# '
# Dest text = 'He served an 8 day suspension for the incident.
# '
# Decoded text = 'He served a 8 day suspension for the incident.
# '
#  =======================
# Input text = 'She took 11th place in event with 503 points .
# '
# Dest text = 'She took 11th place in the event with 503 points.
# '
# Decoded text = 'She took 11th place in the event with 503 points.
# '
#  =======================
# Input text = 'I am not in slightest bit satisfied .
# '
# Dest text = 'I am not in the slightest bit satisfied.
# '
# Decoded text = 'I am not in the slightest bit satisfied.
# '
#  =======================
# Input text = 'The album entered UK Album Charts at # 18 .
# '
# Dest text = 'The album entered the UK Album Charts at #18.
# '
# Decoded text = 'The album entered the UK Album Charts at #18.
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'A music video was not recorded for song .
# '
# Dest text = 'A music video was not recorded for the song.
# '
# Decoded text = 'A music video was not recorded for the song.
# '
#  =======================
# Input text = 'It was opened to public on 24 September 1898 .
# '
# Dest text = 'It was opened to the public on 24 September 1898.
# '
# Decoded text = 'It was opened to the public on 24 September 1898.
# '
#  =======================
# Input text = 'Peru and Chile did not hold border .
# '
# Dest text = 'Peru and Chile did not hold a border.
# '
# Decoded text = 'Peru and Chile did not hold the border.
# '
#  =======================
# Input text = 'It covered area to east of King 's Lynn .
# '
# Dest text = 'It covered an area to the east of King's Lynn.
# '
# Decoded text = 'It covered the area to the east of King's Lynn.
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 25,085 ."
# '
# Dest text = '"The per capita income for the CDP was $25,085."
# '
# Decoded text = '"The per capita income for the CDP was $25,085."
# '
#  =======================
# Input text = '"Cornwall won game 17-3 , scoring 5 tries ."
# '
# Dest text = '"Cornwall won the game 17-3, scoring 5 tries."
# '
# Decoded text = '"Cornwall won the game 17-3, scoring 5 tries."
# '
#  =======================
# Input text = 'All that remained were few drops of water .
# '
# Dest text = 'All that remained were a few drops of water.
# '
# Decoded text = 'All that remained were few drops of the water.
# '
#  =======================
# Input text = 'It was debut release from both bands .
# '
# Dest text = 'It was the debut release from both bands.
# '
# Decoded text = 'It was a debut release from both bands.
# '
#  =======================
# Input text = '"As of 2010 county population was 11,800 ."
# '
# Dest text = '"As of 2010 the county population was 11,800."
# '
# Decoded text = '"As of 2010 the county population was 11,800."
# '
#  =======================
# Input text = ': : : You have diff ?
# '
# Dest text = '::: You have a diff?
# '
# Decoded text = ':::You have a diff?
# '
#  =======================
# Input text = 'People generally eat 5 times day .
# '
# Dest text = 'People generally eat 5 times a day.
# '
# Decoded text = 'People generally eat 5 times a day.
# '
#  =======================
# Input text = 'Roberts then signed one-year deal next day .
# '
# Dest text = 'Roberts then signed a one-year deal the next day.
# '
# Decoded text = 'Roberts then signed a one-year deal next day.
# '
#  =======================
# Input text = '"The per capita income for city was $ 17,235 ."
# '
# Dest text = '"The per capita income for the city was $17,235."
# '
# Decoded text = '"The per capita income for the city was $17,235."
# '
#  =======================
# Input text = 'We 've reached treasur 'd goal .
# '
# Dest text = 'We've reached the treasur'd goal.
# '
# Decoded text = 'We've reached the treasur'd goal.
# '
#  =======================
# Input text = 'The Jedi Odan-Urr later unified system .
# '
# Dest text = 'The Jedi Odan-Urr later unified the system.
# '
# Decoded text = 'The Jedi Odan-Urr later the unified system.
# '
#  =======================
# Input text = 'Ras Darge died few years after that battle .
# '
# Dest text = 'Ras Darge died a few years after that battle.
# '
# Decoded text = 'Ras Darge died a few years after that battle.
# '
#  =======================
# Input text = 'The result of debate was } rename to .
# '
# Dest text = 'The result of the debate was } rename to .
# '
# Decoded text = 'The result of the debate was } rename to .
# '
#  =======================
# Input text = 'Jimmie Johnson won pole .
# '
# Dest text = 'Jimmie Johnson won the pole.
# '
# Decoded text = 'Jimmie Johnson won the pole.
# '
#  =======================
# Input text = 'Bengalis comprise majority of population .
# '
# Dest text = 'Bengalis comprise the majority of the population.
# '
# Decoded text = 'Bengalis comprise majority of the population.
# '
#  =======================
# Input text = 'In 1938 she was given Civil List pension .
# '
# Dest text = 'In 1938 she was given a Civil List pension.
# '
# Decoded text = 'In 1938 she was given the Civil List pension.
# '
#  =======================
# Input text = '"The population was 7,085 at 2010 census ."
# '
# Dest text = '"The population was 7,085 at the 2010 census."
# '
# Decoded text = '"The population was 7,085 at the 2010 census."
# '
#  =======================
# Input text = 'Later it turned out that this was not case .
# '
# Dest text = 'Later it turned out that this was not the case.
# '
# Decoded text = 'Later it turned out that this was not the case.
# '
#  =======================
# Input text = 'He had to leave school early to help family .
# '
# Dest text = 'He had to leave school early to help the family.
# '
# Decoded text = 'He had to leave school early to help the family.
# '
#  =======================
# Input text = 'The state hired Tom Rife to manage building .
# '
# Dest text = 'The state hired Tom Rife to manage the building.
# '
# Decoded text = 'The state hired Tom Rife to manage the building.
# '
#  =======================
# Input text = 'Some of them are among oldest in world .
# '
# Dest text = 'Some of them are among the oldest in the world.
# '
# Decoded text = 'Some of them are among the oldest in the world.
# '
#  =======================
# Input text = 'The result of debate was KEEP .
# '
# Dest text = 'The result of the debate was KEEP.
# '
# Decoded text = 'The result of the debate was KEEP.
# '
#  =======================
# Input text = 'Note that not all records on NDR are correct .
# '
# Dest text = 'Note that not all records on the NDR are correct.
# '
# Decoded text = 'Note that not all records on the NDR are correct.
# '
#  =======================
# Input text = 'Car M1 burned in metro depot in 1973 .
# '
# Dest text = 'Car M1 burned in the metro depot in 1973.
# '
# Decoded text = 'Car M1 burned in a metro depot in 1973.
# '
#  =======================
# Input text = 'Newfoundland became province of Canada in 1949 .
# '
# Dest text = 'Newfoundland became a province of Canada in 1949.
# '
# Decoded text = 'Newfoundland became a province of Canada in 1949.
# '
#  =======================
# Input text = '"The per capita income for city was $ 13,669 ."
# '
# Dest text = '"The per capita income for the city was $13,669."
# '
# Decoded text = '"The per capita income for the city was $13,669."
# '
#  =======================
# Input text = '"You do n't want quite complete list , I hope ."
# '
# Dest text = '"You don't want a quite complete list, I hope."
# '
# Decoded text = '"You don't want quite a complete list, I hope."
# '
#  =======================
# Input text = 'In 1912 first sewer system was built .
# '
# Dest text = 'In 1912 the first sewer system was built.
# '
# Decoded text = 'In 1912 the first sewer system was built.
# '
#  =======================
# Input text = 'Tecmo Cup Football Game was 1993 video game .
# '
# Dest text = 'Tecmo Cup Football Game was a 1993 video game.
# '
# Decoded text = 'Tecmo Cup Football Game was the 1993 video game.
# '
#  =======================
# Input text = 'Same was capital of Empire of Manufahi .
# '
# Dest text = 'Same was the capital of the Empire of Manufahi.
# '
# Decoded text = 'Same was the capital of the Empire of Manufahi.
# '
#  =======================
# Input text = ': **I 've removed excess links now .
# '
# Dest text = ':**I've removed the excess links now.
# '
# Decoded text = ':**I've removed the excess links now.
# '
#  =======================
# Input text = '"1821 in Vienna , d. 1914 ) was also painter ."
# '
# Dest text = '"1821 in Vienna, d. 1914) was also a painter."
# '
# Decoded text = '"1821 in Vienna, d. 1914) was also a painter."
# '
#  =======================
# Input text = 'The result of debate was Delete .
# '
# Dest text = 'The result of the debate was Delete.
# '
# Decoded text = 'The result of the debate was Delete.
# '
#  =======================
# Input text = 'He also worked on improvement of star maps .
# '
# Dest text = 'He also worked on the improvement of star maps.
# '
# Decoded text = 'He also worked on the improvement of star maps.
# '
#  =======================
# Input text = '"He was son of another painter , Bhavani Das ."
# '
# Dest text = '"He was the son of another painter, Bhavani Das."
# '
# Decoded text = '"He was the son of another painter, Bhavani Das."
# '
#  =======================
# Input text = 'She finished year at World No .
# '
# Dest text = 'She finished the year at World No.
# '
# Decoded text = 'She finished the year at World No.
# '
#  =======================
# Input text = 'The median age in city was 50.8 years .
# '
# Dest text = 'The median age in the city was 50.8 years.
# '
# Decoded text = 'The median age in the city was 50.8 years.
# '
#  =======================
# Input text = 'He was dealer in Krefeld .
# '
# Dest text = 'He was a dealer in Krefeld.
# '
# Decoded text = 'He was a dealer in Krefeld.
# '
#  =======================
# Input text = '*Speedy Delete nothing left now but infobox .
# '
# Dest text = '*Speedy Delete nothing left now but the infobox.
# '
# Decoded text = '*Speedy Delete nothing left now but the infobox.
# '
#  =======================
# Input text = 'Fine Art was added as discrete focus in 1945 .
# '
# Dest text = 'Fine Art was added as a discrete focus in 1945.
# '
# Decoded text = 'Fine Art was added as a discrete focus in 1945.
# '
#  =======================
# Input text = 'How did I know he 'd have band ?
# '
# Dest text = 'How did I know he'd have a band?
# '
# Decoded text = 'How did I know he'd have a band?
# '
#  =======================
# Input text = 'Denmark and Finland advanced for playoff A .
# '
# Dest text = 'Denmark and Finland advanced for the playoff A.
# '
# Decoded text = 'Denmark and Finland advanced for the playoff A.
# '
#  =======================
# Input text = 'This spawned American Southern culture .
# '
# Dest text = 'This spawned the American Southern culture.
# '
# Decoded text = 'This spawned the American Southern culture.
# '
#  =======================
# Input text = 'The result of debate was merge/redirect .
# '
# Dest text = 'The result of the debate was merge/redirect.
# '
# Decoded text = 'The result of the debate was merge/redirect.
# '
#  =======================
# Input text = 'Barnes and Trost created label L.M .
# '
# Dest text = 'Barnes and Trost created the label L.M.
# '
# Decoded text = 'Barnes and Trost created the label L.M.
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 5,165 ."
# '
# Dest text = '"The per capita income for the CDP was $5,165."
# '
# Decoded text = '"The per capita income for the CDP was $5,165."
# '
#  =======================
# Input text = 'An article of dress was named after battle .
# '
# Dest text = 'An article of dress was named after the battle.
# '
# Decoded text = 'An article of dress was named after the battle.
# '
#  =======================
# Input text = 'He was raised in strict Catholic household .
# '
# Dest text = 'He was raised in a strict Catholic household.
# '
# Decoded text = 'He was raised in a strict Catholic household.
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 24,333 ."
# '
# Dest text = '"The per capita income for the CDP was $24,333."
# '
# Decoded text = '"The per capita income for the CDP was $24,333."
# '
#  =======================
# Input text = 'Be sure you 're getting on correct title page .
# '
# Dest text = 'Be sure you're getting on the correct title page.
# '
# Decoded text = 'Be sure you're getting on the correct title page.
# '
#  =======================
# Input text = 'Colby was offered post of U.S .
# '
# Dest text = 'Colby was offered the post of U.S.
# '
# Decoded text = 'Colby was offered post of the U.S.
# '
#  =======================
# Input text = 'It is wording I object to .
# '
# Dest text = 'It is the wording I object to.
# '
# Decoded text = 'It is the wording I object to .
# '
#  =======================
# Input text = 'The racial makeup of city was 100.00 % White .
# '
# Dest text = 'The racial makeup of the city was 100.00% White.
# '
# Decoded text = 'The racial makeup of the city was 100.00% White.
# '
#  =======================
# Input text = 'Lars called the team punkest team in MLS .
# '
# Dest text = 'Lars called the team the punkest team in MLS.
# '
# Decoded text = 'Lars called the team punkest team in the MLS.
# '
#  =======================
# Input text = 'Med students get 5 weeks off year .
# '
# Dest text = 'Med students get 5 weeks off a year.
# '
# Decoded text = 'Med students get 5 weeks off the year.
# '
#  =======================
# Input text = 'and bill was abandoned .
# '
# Dest text = 'and the bill was abandoned.
# '
# Decoded text = 'and the bill was abandoned.
# '
#  =======================
# Input text = 'I do n't see much of conflict here .
# '
# Dest text = 'I don't see much of a conflict here.
# '
# Decoded text = 'I don't see much of a conflict here.
# '
#  =======================
# Input text = 'Sayeedi said verdict was not neutral .
# '
# Dest text = 'Sayeedi said the verdict was not neutral.
# '
# Decoded text = 'Sayeedi said the verdict was not neutral.
# '
#  =======================
# Input text = '"The population was 4,460 at 2010 census ."
# '
# Dest text = '"The population was 4,460 at the 2010 census."
# '
# Decoded text = '"The population was 4,460 at the 2010 census."
# '
#  =======================
# Input text = 'Berkeley finally did face rebellion in 1676 .
# '
# Dest text = 'Berkeley finally did face a rebellion in 1676.
# '
# Decoded text = 'Berkeley finally did a face rebellion in 1676.
# '
#  =======================
# Input text = 'Both emperors lived in time of warfare .
# '
# Dest text = 'Both emperors lived in a time of warfare.
# '
# Decoded text = 'Both emperors lived in the time of warfare.
# '
#  =======================
# Input text = 'One day Fred was studying in library .
# '
# Dest text = 'One day Fred was studying in the library.
# '
# Decoded text = 'One day Fred was studying in the library.
# '
#  =======================
# Input text = 'THRUSH 's aim was to conquer world .
# '
# Dest text = 'THRUSH's aim was to conquer the world.
# '
# Decoded text = 'THRUSH's aim was to conquer the world.
# '
#  =======================
# Input text = ': : : you built human ! ?
# '
# Dest text = ':::you built a human!?
# '
# Decoded text = ':::you built a human!?
# '
#  =======================
# Input text = 'The population was 276 at 2000 census .
# '
# Dest text = 'The population was 276 at the 2000 census.
# '
# Decoded text = 'The population was 276 at the 2000 census.
# '
#  =======================
# Input text = 'The entire village was burnt to ground .
# '
# Dest text = 'The entire village was burnt to the ground.
# '
# Decoded text = 'The entire village was burnt to the ground.
# '
#  =======================
# Input text = 'I added footnote for Olympic metric usage .
# '
# Dest text = 'I added a footnote for the Olympic metric usage.
# '
# Decoded text = 'I added a footnote for the Olympic metric usage.
# '
#  =======================
# Input text = '"In 919 , Chu army attacked Jingnan ."
# '
# Dest text = '"In 919, a Chu army attacked Jingnan."
# '
# Decoded text = '"In 919, the Chu army attacked Jingnan."
# '
#  =======================
# Input text = 'Do n't let me be misunderstood : memoir .
# '
# Dest text = 'Don't let me be misunderstood : a memoir.
# '
# Decoded text = 'Don't let me be a misunderstood: memoir.
# '
#  =======================
# Input text = '"The population was 7,101 at 2010 census ."
# '
# Dest text = '"The population was 7,101 at the 2010 census."
# '
# Decoded text = '"The population was 7,101 at the 2010 census."
# '
#  =======================
# Input text = 'These use switching power stage .
# '
# Dest text = 'These use a switching power stage.
# '
# Decoded text = 'These use switching the power stage.
# '
#  =======================
# Input text = '"Well , I have created number of new articles ."
# '
# Dest text = '"Well, I have created a number of new articles."
# '
# ...
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'Stones are an important part of ceremony .
# '
# Dest text = 'Stones are an important part of the ceremony.
# '
# Decoded text = 'Stones are an important part of the ceremony.
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 21,367 ."
# '
# Dest text = '"The per capita income for the CDP was $21,367."
# '
# Decoded text = '"The per capita income for the CDP was $21,367."
# '
#  =======================
# Input text = '"As of 2000 census , population was 928 ."
# '
# Dest text = '"As of the 2000 census, the population was 928."
# '
# Decoded text = '"As of the 2000 census, the population was 928."
# '
#  =======================
# Input text = 'It was descendant of Unetice culture .
# '
# Dest text = 'It was the descendant of the Unetice culture.
# '
# Decoded text = 'It was a descendant of the Unetice culture.
# '
#  =======================
# Input text = 'The racial makeup of CDP was 100.00 % White .
# '
# Dest text = 'The racial makeup of the CDP was 100.00% White.
# '
# Decoded text = 'The racial makeup of the CDP was 100.00% White.
# '
#  =======================
# Input text = 'The song won Grammy in 2000 .
# '
# Dest text = 'The song won a Grammy in 2000.
# '
# Decoded text = 'The song won the Grammy in 2000.
# '
#  =======================
# Input text = 'It was only undeleted for history .
# '
# Dest text = 'It was only undeleted for the history.
# '
# Decoded text = 'It was only undeleted for the history.
# '
#  =======================
# Input text = 'In 2009 remake of Fame was released .
# '
# Dest text = 'In 2009 a remake of Fame was released.
# '
# Decoded text = 'In 2009 the remake of Fame was released.
# '
#  =======================
# Input text = 'He divided plant kingdom in six groups .
# '
# Dest text = 'He divided the plant kingdom in six groups.
# '
# Decoded text = 'He divided the plant kingdom in six groups.
# '
#  =======================
# Input text = '* The Vorlons have visited Earth in past .
# '
# Dest text = '* The Vorlons have visited Earth in the past.
# '
# Decoded text = '* The Vorlons have visited Earth in the past.
# '
#  =======================
# Input text = 'Six of crew were killed .
# '
# Dest text = 'Six of the crew were killed.
# '
# Decoded text = 'Six of the crew were killed.
# '
#  =======================
# Input text = 'The median age in town was 38.2 years .
# '
# Dest text = 'The median age in the town was 38.2 years.
# '
# Decoded text = 'The median age in the town was 38.2 years.
# '
#  =======================
# Input text = 'He has long had interest in comedy .
# '
# Dest text = 'He has long had an interest in comedy.
# '
# Decoded text = 'He has a long had interest in the comedy.
# '
#  =======================
# Input text = '"on album ) , took time to find audience ."
# '
# Dest text = '"on the album), took time to find an audience."
# '
# Decoded text = '"on album), took time to find an audience."
# '
#  =======================
# Input text = 'The result of debate was rename .
# '
# Dest text = 'The result of the debate was rename.
# '
# Decoded text = 'The result of the debate was rename.
# '
#  =======================
# Input text = 'The result of debate was delete .
# '
# Dest text = 'The result of the debate was delete.
# '
# Decoded text = 'The result of the debate was delete.
# '
#  =======================
# Input text = 'The total length of line was 5+1/4 mi .
# '
# Dest text = 'The total length of the line was 5+1/4 mi.
# '
# Decoded text = 'The total length of the line was 5+1/4 mi.
# '
#  =======================
# Input text = '*Keep-The user who created this is newbie .
# '
# Dest text = '*Keep-The user who created this is a newbie.
# '
# Decoded text = '*Keep-The user who created this is a newbie.
# '
#  =======================
# Input text = 'The seat of municipality was in Asprangeloi .
# '
# Dest text = 'The seat of the municipality was in Asprangeloi.
# '
# Decoded text = 'The seat of the municipality was in Asprangeloi.
# '
#  =======================
# Input text = 'The building was constructed in 1950s .
# '
# Dest text = 'The building was constructed in the 1950s.
# '
# Decoded text = 'The building was constructed in the 1950s.
# '
#  =======================
# Input text = 'This violated secrecy of ballot .
# '
# Dest text = 'This violated the secrecy of the ballot.
# '
# Decoded text = 'This violated secrecy of the ballot.
# '
#  =======================
# Input text = 'They earned derisive label Mink Brigade .
# '
# Dest text = 'They earned the derisive label the Mink Brigade.
# '
# Decoded text = 'They earned the derisive label Mink Brigade.
# '
#  =======================
# Input text = 'The result of debate was Delete .
# '
# Dest text = 'The result of the debate was Delete.
# '
# Decoded text = 'The result of the debate was Delete.
# '
#  =======================
# Input text = 'A passenger in other car later died .
# '
# Dest text = 'A passenger in the other car later died.
# '
# Decoded text = 'A passenger in the other car later died.
# '
#  =======================
# Input text = 'The result of debate was No consensus .
# '
# Dest text = 'The result of the debate was No consensus.
# '
# Decoded text = 'The result of the debate was No consensus.
# '
#  =======================
# Input text = 'Gold mining was main economic activity .
# '
# Dest text = 'Gold mining was the main economic activity.
# '
# Decoded text = 'Gold mining was a main economic activity.
# '
#  =======================
# Input text = '"Confirmed : , , and are same user ."
# '
# Dest text = '"Confirmed: , , and are the same user."
# '
# Decoded text = '"Confirmed: , , and are the same user."
# '
#  =======================
# Input text = '"Lutenists play lute , string instrument ."
# '
# Dest text = '"Lutenists play the lute, a string instrument."
# '
# Decoded text = '"Lutenists play a lute, string instrument."
# '
#  =======================
# Input text = '*Delete I disagree with age test .
# '
# Dest text = '*Delete I disagree with the age test.
# '
# Decoded text = '*Delete I disagree with the age test.
# '
#  =======================
# Input text = 'The median age in city was 39.9 years .
# '
# Dest text = 'The median age in the city was 39.9 years.
# '
# Decoded text = 'The median age in the city was 39.9 years.
# '
#  =======================
# Input text = 'Brandon Gray started site in 1999 .
# '
# Dest text = 'Brandon Gray started the site in 1999.
# '
# Decoded text = 'Brandon Gray started the site in 1999.
# '
#  =======================
# Input text = '* A video on how CVN-77 was made .
# '
# Dest text = '* A video on how the CVN-77 was made.
# '
# Decoded text = '* A video on the how CVN-77 was made.
# '
#  =======================
# Input text = 'They are always in press making huge claims .
# '
# Dest text = 'They are always in the press making huge claims.
# '
# Decoded text = 'They are always in the press making huge claims.
# '
#  =======================
# Input text = '"The per capita income for town was $ 11,750 ."
# '
# Dest text = '"The per capita income for the town was $11,750."
# '
# Decoded text = '"The per capita income for the town was $11,750."
# '
#  =======================
# Input text = 'In 1410 court decided in favour of Grey .
# '
# Dest text = 'In 1410 a court decided in favour of Grey.
# '
# Decoded text = 'In 1410 the court decided in favour of Grey.
# '
#  =======================
# Input text = '* { Congregation } We lift them to Lord .
# '
# Dest text = '*{Congregation} We lift them to the Lord.
# '
# Decoded text = '* {Congregation} We lift them to the Lord.
# '
#  =======================
# Input text = 'The link to awards is on movies own site .
# '
# Dest text = 'The link to the awards is on the movies own site.
# '
# Decoded text = 'The link to awards is on the movies own site.
# '
#  =======================
# Input text = 'Everyone wanted to hear piece again .
# '
# Dest text = 'Everyone wanted to hear the piece again.
# '
# Decoded text = 'Everyone wanted to hear the piece again.
# '
#  =======================
# Input text = 'He shared podium with USA 's Marvin Johnson .
# '
# Dest text = 'He shared the podium with USA's Marvin Johnson.
# '
# Decoded text = 'He shared the podium with USA's Marvin Johnson.
# '
#  =======================
# Input text = 'This was incomplete AfD nomination .
# '
# Dest text = 'This was an incomplete AfD nomination.
# '
# Decoded text = 'This was the incomplete AfD nomination.
# '
#  =======================
# Input text = '"In northwest are Lugbara , 4 % ."
# '
# Dest text = '"In the northwest are the Lugbara, 4%."
# '
# Decoded text = '"In the northwest are Lugbara, 4%."
# '
#  =======================
# Input text = 'There were 216 in country .
# '
# Dest text = 'There were 216 in the country.
# '
# Decoded text = 'There were 216 in the country.
# '
#  =======================
# Input text = 'A music video for song was also released .
# '
# Dest text = 'A music video for the song was also released.
# '
# Decoded text = 'A music video for the song was also released.
# '
#  =======================
# Input text = 'Tonight I imposed 24 hour ban .
# '
# Dest text = 'Tonight I imposed a 24 hour ban.
# '
# Decoded text = 'Tonight I imposed a 24 hour ban.
# '
#  =======================
# Input text = 'Very few structures exist near airfield .
# '
# Dest text = 'Very few structures exist near the airfield.
# '
# Decoded text = 'Very few structures exist near the airfield.
# '
#  =======================
# Input text = 'He was three-year starter at Ripley ( Miss . )
# '
# Dest text = 'He was a three-year starter at Ripley (Miss.)
# '
# Decoded text = 'He was a three-year starter at Ripley (Miss.)
# '
#  =======================
# Input text = '"In 1969 , he became member of the SPD ."
# '
# Dest text = '"In 1969, he became a member of the SPD."
# '
# Decoded text = '"In 1969, he became a member of the SPD."
# '
#  =======================
# Input text = '"The per capita income for town was $ 15,931 ."
# '
# Dest text = '"The per capita income for the town was $15,931."
# '
# Decoded text = '"The per capita income for the town was $15,931."
# '
#  =======================
# Input text = 'The album became massive success commercially .
# '
# Dest text = 'The album became a massive success commercially.
# '
# Decoded text = 'The album became a massive success commercially.
# '
#  =======================
# Input text = 'The end values are determined by auction .
# '
# Dest text = 'The end values are determined by an auction.
# '
# Decoded text = 'The end values are determined by the auction.
# '
#  =======================
# Input text = 'He did not point gun at Snee or threaten him .
# '
# Dest text = 'He did not point the gun at Snee or threaten him.
# '
# Decoded text = 'He did not point a gun at Snee or threaten him.
# '
#  =======================
# Input text = 'I do n't understand what problem is .
# '
# Dest text = 'I don't understand what the problem is.
# '
# Decoded text = 'I don't understand what the problem is.
# '
#  =======================
# Input text = 'The schools nickname was Knights .
# '
# Dest text = 'The schools nickname was the Knights.
# '
# Decoded text = 'The schools nickname was the Knights.
# '
#  =======================
# Input text = 'The bankruptcy was novel one .
# '
# Dest text = 'The bankruptcy was a novel one.
# '
# Decoded text = 'The bankruptcy was a novel one.
# '
#  =======================
# Input text = 'The album entered Billboard 200 at No .
# '
# Dest text = 'The album entered the Billboard 200 at No.
# '
# Decoded text = 'The album entered the Billboard 200 at No.
# '
#  =======================
# Input text = 'The rebellion failed due to number of reasons .
# '
# Dest text = 'The rebellion failed due to a number of reasons.
# '
# Decoded text = 'The rebellion failed due to a number of reasons.
# '
#  =======================
# Input text = 'As result Aarti and Raja separate .
# '
# Dest text = 'As a result Aarti and Raja separate.
# '
# Decoded text = 'As a result Aarti and Raja separate.
# '
#  =======================
# Input text = 'We are trying to take Gandhian approach .
# '
# Dest text = 'We are trying to take the Gandhian approach.
# '
# Decoded text = 'We are trying to take the Gandhian approach.
# '
#  =======================
# Input text = '"The population was 3,072 at 2000 census ."
# '
# Dest text = '"The population was 3,072 at the 2000 census."
# '
# Decoded text = '"The population was 3,072 at the 2000 census."
# '
#  =======================
# Input text = 'I have created first Wikimoney lottery at .
# '
# Dest text = 'I have created the first Wikimoney lottery at .
# '
# Decoded text = 'I have created the first Wikimoney lottery at .
# '
#  =======================
# Input text = '"The per capita income for CDP was $ 18,392 ."
# '
# Dest text = '"The per capita income for the CDP was $18,392."
# '
# Decoded text = '"The per capita income for the CDP was $18,392."
# '
#  =======================
# Input text = 'An earlier name for town was Macon .
# '
# Dest text = 'An earlier name for the town was Macon.
# '
# Decoded text = 'An earlier name for the town was Macon.
# '
#  =======================
# Input text = '"Case Plow Works , was independent business ."
# '
# Dest text = '"Case Plow Works, was an independent business."
# '
# Decoded text = '"Case Plow Works, was the independent business."
# '
#  =======================
# Input text = 'The population was 989 at 2010 census .
# '
# Dest text = 'The population was 989 at the 2010 census.
# '
# Decoded text = 'The population was 989 at the 2010 census.
# '
#  =======================
# Input text = 'I met lot of people and made lot of friends .
# '
# Dest text = 'I met a lot of people and made a lot of friends.
# '
# Decoded text = 'I met a lot of people and made a lot of friends.
# '
#  =======================
# Input text = 'The result of debate was } no consensus .
# '
# Dest text = 'The result of the debate was } no consensus.
# '
# Decoded text = 'The result of the debate was } no consensus.
# '
#  =======================
# Input text = 'It was given recording in 1987 .
# '
# Dest text = 'It was given a recording in 1987.
# '
# Decoded text = 'It was given a recording in 1987.
# '
#  =======================
# Input text = 'In 1948 season there were joint managers .
# '
# Dest text = 'In the 1948 season there were joint managers.
# '
# Decoded text = 'In the 1948 season there were joint managers.
# '
#  =======================
# Input text = '"Drivers ' Mart , competitor , was purchased ."
# '
# Dest text = '"Drivers' Mart, a competitor, was purchased."
# '
# Decoded text = '"Drivers' Mart, the competitor, was purchased."
# '
#  =======================
# Input text = 'The result of debate was rename .
# '
# Dest text = 'The result of the debate was rename.
# '
# Decoded text = 'The result of the debate was rename.
# '
#  =======================
# Input text = '"I 'm SG-1 fan , but I 'm a WP editor first ."
# '
# Dest text = '"I'm an SG-1 fan, but I'm a WP editor first."
# '
# Decoded text = '"I'm a SG-1 fan, but I'm a WP editor first."
# '
#  =======================
# Input text = 'It was carrying cargo of gascoal .
# '
# Dest text = 'It was carrying a cargo of gascoal.
# '
# Decoded text = 'It was carrying a cargo of gascoal.
# '
#  =======================
# Input text = 'The population was 710 at 2000 census .
# '
# Dest text = 'The population was 710 at the 2000 census.
# '
# Decoded text = 'The population was 710 at the 2000 census.
# '
#  =======================
# Input text = 'Everyone was in love with La-5 .
# '
# Dest text = 'Everyone was in love with the La-5.
# '
# Decoded text = 'Everyone was in love with the La-5.
# '
#  =======================
# Input text = 'He also built gristmill along Carpenter 's Run .
# '
# Dest text = 'He also built a gristmill along Carpenter's Run.
# '
# Decoded text = 'He also built a gristmill along Carpenter's Run.
# '
#  =======================
# Input text = 'During this period brewery was expanded .
# '
# Dest text = 'During this period the brewery was expanded.
# '
# Decoded text = 'During this period the brewery was expanded.
# '
#  =======================
# Input text = 'Llywelyn and Lee obtained divorce in 2001 .
# '
# Dest text = 'Llywelyn and Lee obtained a divorce in 2001.
# '
# Decoded text = 'Llywelyn and Lee obtained a divorce in 2001.
# '
#  =======================
# Input text = 'The result of debate was to delete .
# '
# Dest text = 'The result of the debate was to delete.
# '
# Decoded text = 'The result of the debate was to delete.
# '
#  =======================

# %%
evaluate_model(random.sample(train_data_list, k=10))

# %% [markdown]
# We also evaluate in the validation set to get a feeling of the performance differences

# %% [markdown]
# # The key evaluation on the test set

# %% [markdown]
# Below is the performance of the model on the unseen dataset

# %%
evaluate_model(training_manager.test_set)

# %% [markdown]
# Number of corrected decoding =  66564 , out of  88064
# Accuracy = 0.755859375
